# %%
import re
import csv
import json
from pathlib import Path
import openpyxl
from openpyxl.drawing.image import Image
import os
import cv2
import pandas as pd
from glob import glob

# %% [markdown]
# ### 从lua到表格

# %%
class TranslationMods:
    def __init__(self, mod_dir):
        super().__init__()
        self.mod_info = []
        self.base_dir = mod_dir
        self.lua_dirs = glob(mod_dir + "/**/*.lua", recursive=True)

        self.lua_table_begin_pattern = r'local\s+\w+\s*=\s*\{'
        self.patterns = {
            'object_type': r'object_type\s*=\s*["\']([^"\']*)["\']',
            'name': r'name\s*=\s*["\']([^"\']*)["\']',
            'set': r'set\s*=\s*["\']([^"\']*)["\']',
            'key': r'key\s*=\s*["\']([^"\']*)["\']',
            'path': r'path\s*=\s*["\']([^"\']*)["\']',
            'px': r'px\s*=\s*(\d+)',
            'py': r'py\s*=\s*(\d+)',
            'atlas': r'atlas\s*=\s*["\']([^"\']*)["\']',
            'loc_txt': r'loc_txt\s*=\s*\{[^}]*?name\s*=\s*["\']([^"\']*)["\']\s*,\s*text\s*=',
            'rarity': r'rarity\s*=\s*(\d+)',
            'cost': r'cost\s*=\s*(\d+)',
            'pos': r"pos\s*=\s*\{\s*x\s*=\s*(\d+)\s*,\s*y\s*=\s*(\d+)",
            
        }
        self.atlasDict = {}
        
    def load_atlas(self , file_path):
        pattern  = r'SMODS\.Atlas\(\s*{\s*key\s*=\s*"(.*?)",\s*path\s*=\s*"(.*?)",\s*px\s*=\s*(\d+),\s*py\s*=\s*(\d+)\s*'
        with open(file_path, 'r', encoding='utf-8') as f:
            input_str = f.read()
            matches = re.findall(pattern, input_str)
    
            for match in matches:
                key, path, px, py = match
                
                self.atlasDict[key] = {
                    "path" : path,
                    "px" : px ,
                    "py" : py
                }
        
    def _match_table(self, s, begin_idx):
        table = ""
        n = len(s)
        l = 0 
        r = 0
        while begin_idx < n:
            table += s[begin_idx]
            if s[begin_idx] == "{":
                l = l + 1
            elif s[begin_idx] == "}":
                r = r + 1
            begin_idx += 1
            if l == r :
                return table
        return table
    
    def _table_clean(self, table):
        table = re.sub(r'--.*?(?=["\n])', '', table)
        table = table.strip().replace("\t","").replace("\n","").replace("'", '"')
        table = re.sub(r',(\s*[\]\}])', r'\1', table)
        table = table.replace('n"t', "n't")
        table = table.replace('i"m', "i'm")
        table = table.replace('n\\"t', "n't")
        
        return f"[{table[1:-1]}]"

    def conver(self, lua_string):
        results = {}
        for field, pattern in self.patterns.items():
            match = re.search(pattern, lua_string, re.DOTALL)
            if match:
                # 如果有匹配到 loc_txt，需要进一步处理多行字符串
                if field == 'loc_txt':
                    name = match.group(1)
                    table = self._match_table(lua_string,match.end()+1)
                    table = self._table_clean(table)
                    
                    try:
                        json_texts = json.loads(table)
                        results[field] = {'name': name, 'text': json_texts}
                    except Exception as e:
                        print(e)
                        print(table)
                        results[field] = ""
                        # raise e

                elif field == 'pos':
                    match = re.search(pattern, lua_string)
                    if match:
                        results[field] = { "x" : int(match.group(1)) ,"y" : int(match.group(2))}
                else:
                    results[field] = match.group(1)
            else :
                results[field] = ""
        return results
    
        
        
    def prase_files(self):
        for mod_file in self.lua_dirs :
            fname = os.path.basename(mod_file)
            with open(mod_file, 'r', encoding='utf-8') as f:
                content = f.read()

            self.load_atlas(mod_file)
            lua_table_begin_match = re.finditer(self.lua_table_begin_pattern, content)

            for match in lua_table_begin_match:
                ed = match.end() - 1
                tb = self._match_table(content ,ed)
                results = self.conver(tb)
                
                if results["object_type"] == "Atlas":
                    self.atlasDict[results["key"]] = {
                        "path" : results["path"],
                        "px" : results["px"] ,
                        "py" : results["py"]
                    }
                elif results["loc_txt"] != "" :
                    results["file_name"] = mod_file
                    results["table_begin_idx"] = ed
                    results["table_len"] = len(tb)
                
                    self.mod_info.append(results)
                    
        print(f"全部完成，一共{len(self.mod_info)}条")
        
        
    def _flatten_dict(self,item):
        return {
            'file_name': str(item['file_name']),
            'object_type': item['object_type'],
            'name': item['name'],
            'set' : item['object_type'] if item['set'] =='' else item['set'],
            'key': item['key'],
            'loc_txt_name': item['loc_txt']['name'],
            'T_loc_txt_name': item['T_loc_txt_name'] if 'T_loc_txt_name' in item.keys() else '',
            'loc_txt_text': '\n'.join(item['loc_txt']['text']),
            'T_loc_txt_text': item['T_loc_txt_text'] if 'T_loc_txt_text' in item.keys() else '',
            'cost' : item['cost'],
            'rarity': item['rarity']
        }
        
    def crop_image(self ,img_path, item):
        key = item['atlas']
        x = item['pos']['x']
        y = item['pos']['y']
        
        # 大图片路径
        large_img_path =os.path.join(self.base_dir, "assets\\1x\\" , self.atlasDict[key]["path"]) 
        # print(large_img_path)
        # 小图片的尺寸
        small_width = int(self.atlasDict[key]["px"])
        small_height = int(self.atlasDict[key]["py"])
        # 读取大图
        large_img = cv2.imread(large_img_path)
        # 计算小图的位置（裁剪区域）
        start_x = x * small_width
        start_y = y * small_height
        end_x = start_x + small_width
        end_y = start_y + small_height
        
        # 裁剪出小图
        small_img = large_img[start_y:end_y, start_x:end_x]
        cv2.imwrite(img_path, small_img)
        
    def export_excel(self,excel_path="output.xlsx",with_img = False):
        pixel_to_excel_width = 0.75
        pixel_to_excel_height = 0.75

        
        flattened_data = [self._flatten_dict(item) for item in self.mod_info]
        df = pd.DataFrame(flattened_data)
        df.to_excel(excel_path, index=False, engine='xlsxwriter')
        
        if with_img:
            wb = openpyxl.load_workbook(excel_path)
            ws = wb.active
            for idx,item in zip(range(len(self.mod_info)),self.mod_info):
                if item["atlas"] in self.atlasDict and item['pos'] != '':
                    img_path =f"tmp/tempimg-{idx+1}.png"
                    self.crop_image(img_path , item)
                    img = Image(img_path)
                    
                    cell = f'L{idx+2}'
                    img.anchor  = cell
                    ws.add_image(img)  # 将图片插入到单元格H2
                    
                    # 设置列宽和行高
                    col_letter = cell[0]  # 列字母
                    row_num = int(cell[1:])  # 行号
                    
                    # 设置列宽
                    # img_width = int(self.atlasDict[item["atlas"]]["px"])
                    # img_height = int(self.atlasDict[item["atlas"]]["py"])
                    ws.column_dimensions[col_letter].width = 80
                    ws.row_dimensions[row_num].height = 100
                    
                    # os.remove(img_path)
                
            wb.save(excel_path)
            
                
        
    def import_from_excel(self, csv):
        
        pass
    
    def export_to_lua(self):
        
        pass

# %%
def filter(T):
    return T[(T['T.loc_txt.name'].notna()) & (T['T.loc_txt.name'] != '') |
                (T['T.loc_txt.text'].notna()) & (T['T.loc_txt.text'] != '')]

# %%
cryptidmods = TranslationMods("cryptid")
cryptidmods.prase_files()
# Out:
# 全部完成，一共277条

# %%
cryptidmods.mod_info
# Out:
# [{'object_type': 'Back',
#   'name': 'cry-Blank',
#   'set': '',
#   'key': 'blank',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'blank',
#   'loc_txt': {'name': 'Blank Deck', 'text': ['{C:inactive,E:1}Does nothing?']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 1, 'y': 0},
#   'file_name': 'cryptid\\Items\\Antimatter.lua',
#   'table_begin_idx': 15,
#   'table_len': 235},
#  {'object_type': 'Back',
#   'name': 'cry-Antimatter',
#   'set': '',
#   'key': 'antimatter',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'antimatter',
#   'loc_txt': {'name': 'Antimatter Deck',
#    'text': ['Applies the {C:legendary,E:1}upsides{}',
#     'of {C:attention}every{} deck']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 2, 'y': 0},
#   'file_name': 'cryptid\\Items\\Antimatter.lua',
#   'table_begin_idx': 394,
#   'table_len': 5024},
#  {'object_type': 'Blind',
#   'name': 'cry-oldox',
#   'set': '',
#   'key': 'oldox',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'nostalgia',
#   'loc_txt': {'name': 'Nostalgic Ox',
#    'text': ['All hands start', 'with 0 Chips']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 0},
#   'file_name': 'cryptid\\Items\\Blinds.lua',
#   'table_begin_idx': 1628,
#   'table_len': 597},
#  {'object_type': 'Blind',
#   'name': 'cry-oldhouse',
#   'set': '',
#   'key': 'oldhouse',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'nostalgia',
#   'loc_txt': {'name': 'Nostalgic House', 'text': ['No Full Houses']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 2},
#   'file_name': 'cryptid\\Items\\Blinds.lua',
#   'table_begin_idx': 2243,
#   'table_len': 622},
#  {'object_type': 'Blind',
#   'name': 'cry-oldarm',
#   'set': '',
#   'key': 'oldarm',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'nostalgia',
#   'loc_txt': {'name': 'Nostalgic Arm',
#    'text': ['Must play 4', 'or fewer cards']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 3},
#   'file_name': 'cryptid\\Items\\Blinds.lua',
#   'table_begin_idx': 2881,
#   'table_len': 633},
#  {'object_type': 'Blind',
#   'name': 'cry-oldfish',
#   'set': '',
#   'key': 'oldfish',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'nostalgia',
#   'loc_txt': {'name': 'Nostalgic Fish',
#    'text': ['All hands start', 'with 1 Mult']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 4},
#   'file_name': 'cryptid\\Items\\Blinds.lua',
#   'table_begin_idx': 3531,
#   'table_len': 608},
#  {'object_type': 'Blind',
#   'name': 'cry-oldmanacle',
#   'set': '',
#   'key': 'oldmanacle',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'nostalgia',
#   'loc_txt': {'name': 'Nostalgic Manacle',
#    'text': ['Divide Mult by discards']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 5},
#   'file_name': 'cryptid\\Items\\Blinds.lua',
#   'table_begin_idx': 4159,
#   'table_len': 646},
#  {'object_type': 'Blind',
#   'name': 'cry-oldserpent',
#   'set': '',
#   'key': 'oldserpent',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'nostalgia',
#   'loc_txt': {'name': 'Nostalgic Serpent',
#    'text': ['Divide Mult by level', 'of played poker hand']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 6},
#   'file_name': 'cryptid\\Items\\Blinds.lua',
#   'table_begin_idx': 4825,
#   'table_len': 682},
#  {'object_type': 'Blind',
#   'name': 'cry-oldpillar',
#   'set': '',
#   'key': 'oldpillar',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'nostalgia',
#   'loc_txt': {'name': 'Nostalgic Pillar', 'text': ['No Straights']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 7},
#   'file_name': 'cryptid\\Items\\Blinds.lua',
#   'table_begin_idx': 5526,
#   'table_len': 619},
#  {'object_type': 'Blind',
#   'name': 'cry-oldflint',
#   'set': '',
#   'key': 'oldflint',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'nostalgia',
#   'loc_txt': {'name': 'Nostalgic Flint', 'text': ['No Flushes']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 8},
#   'file_name': 'cryptid\\Items\\Blinds.lua',
#   'table_begin_idx': 6163,
#   'table_len': 609},
#  {'object_type': 'Blind',
#   'name': 'cry-oldmark',
#   'set': '',
#   'key': 'oldmark',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'nostalgia',
#   'loc_txt': {'name': 'Nostalgic Mark',
#    'text': ['No hands that', 'contain a Pair']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 1},
#   'file_name': 'cryptid\\Items\\Blinds.lua',
#   'table_begin_idx': 6789,
#   'table_len': 633},
#  {'object_type': 'Blind',
#   'name': 'cry-Tax',
#   'set': '',
#   'key': 'tax',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'blinds',
#   'loc_txt': {'name': 'The Tax',
#    'text': ['Score per hand capped at', '0.4X blind requirements']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 0},
#   'file_name': 'cryptid\\Items\\Blinds.lua',
#   'table_begin_idx': 7435,
#   'table_len': 555},
#  {'object_type': 'Blind',
#   'name': 'cry-box',
#   'set': '',
#   'key': 'box',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'blinds',
#   'loc_txt': {'name': 'The Box',
#    'text': ['All Common Jokers', 'are debuffed']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 8},
#   'file_name': 'cryptid\\Items\\Blinds.lua',
#   'table_begin_idx': 8003,
#   'table_len': 540},
#  {'object_type': 'Blind',
#   'name': 'cry-Clock',
#   'set': '',
#   'key': 'clock',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'blinds',
#   'loc_txt': {'name': 'The Clock',
#    'text': ['+0.1X blind requirements every', '3 seconds spent this ante']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 1},
#   'file_name': 'cryptid\\Items\\Blinds.lua',
#   'table_begin_idx': 8558,
#   'table_len': 843},
#  {'object_type': 'Blind',
#   'name': 'cry-Trick',
#   'set': '',
#   'key': 'trick',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'blinds',
#   'loc_txt': {'name': 'The Trick',
#    'text': ['After each hand, flip all', 'face-up cards held in hand']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 3},
#   'file_name': 'cryptid\\Items\\Blinds.lua',
#   'table_begin_idx': 9416,
#   'table_len': 1292},
#  {'object_type': 'Blind',
#   'name': 'cry-Joke',
#   'set': '',
#   'key': 'joke',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'blinds',
#   'loc_txt': {'name': 'The Joke',
#    'text': ['If score is >2X requirements,', 'set ante to multiple of #1#']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 4},
#   'file_name': 'cryptid\\Items\\Blinds.lua',
#   'table_begin_idx': 10723,
#   'table_len': 827},
#  {'object_type': 'Blind',
#   'name': 'cry-hammer',
#   'set': '',
#   'key': 'hammer',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'blinds',
#   'loc_txt': {'name': 'The Hammer',
#    'text': ['All cards with odd', 'rank are debuffed']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 9},
#   'file_name': 'cryptid\\Items\\Blinds.lua',
#   'table_begin_idx': 11566,
#   'table_len': 771},
#  {'object_type': 'Blind',
#   'name': 'cry-magic',
#   'set': '',
#   'key': 'magic',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'blinds',
#   'loc_txt': {'name': 'The Magic',
#    'text': ['All cards with even', 'rank are debuffed']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 12},
#   'file_name': 'cryptid\\Items\\Blinds.lua',
#   'table_begin_idx': 12352,
#   'table_len': 769},
#  {'object_type': 'Blind',
#   'name': 'cry-windmill',
#   'set': '',
#   'key': 'windmill',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'blinds',
#   'loc_txt': {'name': 'The Windmill',
#    'text': ['All Uncommon Jokers', 'are debuffed']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 10},
#   'file_name': 'cryptid\\Items\\Blinds.lua',
#   'table_begin_idx': 13139,
#   'table_len': 558},
#  {'object_type': 'Blind',
#   'name': 'cry-striker',
#   'set': '',
#   'key': 'striker',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'blinds',
#   'loc_txt': {'name': 'The Striker',
#    'text': ['All Rare Jokers', 'are debuffed']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 13},
#   'file_name': 'cryptid\\Items\\Blinds.lua',
#   'table_begin_idx': 13714,
#   'table_len': 551},
#  {'object_type': 'Blind',
#   'name': 'cry-shackle',
#   'set': '',
#   'key': 'shackle',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'blinds',
#   'loc_txt': {'name': 'The Shackle',
#    'text': ['All Negative Jokers', 'are debuffed']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 15},
#   'file_name': 'cryptid\\Items\\Blinds.lua',
#   'table_begin_idx': 14282,
#   'table_len': 839},
#  {'object_type': 'Blind',
#   'name': 'cry-pin',
#   'set': '',
#   'key': 'pin',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'blinds',
#   'loc_txt': {'name': 'The Pin',
#    'text': ['Jokers with Epic or higher', 'rarity are debuffed']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 14},
#   'file_name': 'cryptid\\Items\\Blinds.lua',
#   'table_begin_idx': 15134,
#   'table_len': 968},
#  {'object_type': 'Blind',
#   'name': 'cry-pinkbow',
#   'set': '',
#   'key': 'pinkbow',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'blinds',
#   'loc_txt': {'name': 'Pink Bow',
#    'text': ['Randomize rank of cards', 'held in hand on play']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 11},
#   'file_name': 'cryptid\\Items\\Blinds.lua',
#   'table_begin_idx': 16119,
#   'table_len': 466},
#  {'object_type': 'Blind',
#   'name': 'cry-Lavender Loop',
#   'set': '',
#   'key': 'lavender_loop',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'blinds',
#   'loc_txt': {'name': 'Lavender Loop',
#    'text': ['1.25X blind requirements every', '1.5 seconds spent this round']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 2},
#   'file_name': 'cryptid\\Items\\Blinds.lua',
#   'table_begin_idx': 16608,
#   'table_len': 1438},
#  {'object_type': 'Blind',
#   'name': 'cry-tornado',
#   'set': '',
#   'key': 'tornado',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'blinds',
#   'loc_txt': {'name': 'Turquoise Tornado',
#    'text': ['#1# in #2# chance for', 'played hand to not score']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 16},
#   'file_name': 'cryptid\\Items\\Blinds.lua',
#   'table_begin_idx': 18063,
#   'table_len': 951},
#  {'object_type': 'Blind',
#   'name': 'cry-Vermillion Virus',
#   'set': '',
#   'key': 'vermillion_virus',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'blinds',
#   'loc_txt': {'name': 'Vermillion Virus',
#    'text': ['One random Joker', 'replaced every hand']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 5},
#   'file_name': 'cryptid\\Items\\Blinds.lua',
#   'table_begin_idx': 19087,
#   'table_len': 1065},
#  {'object_type': 'Blind',
#   'name': 'cry-Sapphire Stamp',
#   'set': '',
#   'key': 'sapphire_stamp',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'blinds',
#   'loc_txt': {'name': 'Sapphire Stamp',
#    'text': ['Select an extra card, deselect', 'random card before scoring']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 6},
#   'file_name': 'cryptid\\Items\\Blinds.lua',
#   'table_begin_idx': 20177,
#   'table_len': 1174},
#  {'object_type': 'Blind',
#   'name': 'cry-Obsidian Orb',
#   'set': 'Blind',
#   'key': 'obsidian_orb',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'blinds',
#   'loc_txt': {'name': 'Obsidian Orb',
#    'text': ['Applies abilities of', 'all defeated bosses']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 7},
#   'file_name': 'cryptid\\Items\\Blinds.lua',
#   'table_begin_idx': 21374,
#   'table_len': 17498},
#  {'object_type': 'Booster',
#   'name': 'Program Pack',
#   'set': '',
#   'key': 'code_normal_1',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'pack',
#   'loc_txt': {'name': 'Program Pack',
#    'text': ['Choose {C:attention}#1#{} of up to',
#     '{C:attention}#2#{C:cry_code} Code{} cards']},
#   'rarity': '',
#   'cost': '4',
#   'pos': {'x': 0, 'y': 0},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 658,
#   'table_len': 886},
#  {'object_type': 'Booster',
#   'name': 'Program Pack',
#   'set': '',
#   'key': 'code_normal_2',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'pack',
#   'loc_txt': {'name': 'Program Pack',
#    'text': ['Choose {C:attention}#1#{} of up to',
#     '{C:attention}#2#{C:cry_code} Code{} cards']},
#   'rarity': '',
#   'cost': '4',
#   'pos': {'x': 1, 'y': 0},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 1559,
#   'table_len': 886},
#  {'object_type': 'Booster',
#   'name': 'Jumbo Program Pack',
#   'set': '',
#   'key': 'code_jumbo_1',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'pack',
#   'loc_txt': {'name': 'Jumbo Program Pack',
#    'text': ['Choose {C:attention}#1#{} of up to',
#     '{C:attention}#2#{C:cry_code} Code{} cards']},
#   'rarity': '',
#   'cost': '6',
#   'pos': {'x': 2, 'y': 0},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 2460,
#   'table_len': 891},
#  {'object_type': 'Booster',
#   'name': 'Mega Program Pack',
#   'set': '',
#   'key': 'code_mega_1',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'pack',
#   'loc_txt': {'name': 'Mega Program Pack',
#    'text': ['Choose {C:attention}#1#{} of up to',
#     '{C:attention}#2#{C:cry_code} Code{} cards']},
#   'rarity': '',
#   'cost': '8',
#   'pos': {'x': 3, 'y': 0},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 3366,
#   'table_len': 889},
#  {'object_type': 'Tag',
#   'name': 'Console Tag',
#   'set': 'Other',
#   'key': 'console',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'tag_cry',
#   'loc_txt': {'name': 'Console Tag',
#    'text': ['Gives a free', '{C:cry_code}Program Pack']},
#   'rarity': '',
#   'cost': '0',
#   'pos': {'x': 3, 'y': 2},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 4272,
#   'table_len': 1256},
#  {'object_type': 'Consumable',
#   'name': 'cry-Crash',
#   'set': 'Code',
#   'key': 'crash',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'code',
#   'loc_txt': {'name': '://CRASH', 'text': ["{C:cry_code,E:1}Don't."]},
#   'rarity': '',
#   'cost': '4',
#   'pos': {'x': 0, 'y': 0},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 5543,
#   'table_len': 773},
#  {'object_type': 'Consumable',
#   'name': 'cry-Payload',
#   'set': 'Code',
#   'key': 'payload',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'code',
#   'loc_txt': {'name': '://PAYLOAD',
#    'text': ['Next defeated Blind', 'gives {C:cry_code}X#1#{} interest']},
#   'rarity': '',
#   'cost': '4',
#   'pos': {'x': 1, 'y': 0},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 6334,
#   'table_len': 834},
#  {'object_type': 'Consumable',
#   'name': 'cry-Reboot',
#   'set': 'Code',
#   'key': 'reboot',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'code',
#   'loc_txt': {'name': '://REBOOT',
#    'text': ['Replenish {C:blue}Hands{} and {C:red}Discards{},',
#     'return {C:cry_code}all{} cards to deck',
#     'and draw a {C:cry_code}new{} hand']},
#   'rarity': '',
#   'cost': '4',
#   'pos': {'x': 2, 'y': 0},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 7184,
#   'table_len': 1352},
#  {'object_type': 'Consumable',
#   'name': 'cry-Revert',
#   'set': 'Code',
#   'key': 'revert',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'code',
#   'loc_txt': {'name': '://REVERT',
#    'text': ['Set {C:cry_code}game state{} to',
#     'start of {C:cry_code}this Ante{}']},
#   'rarity': '',
#   'cost': '4',
#   'pos': {'x': 3, 'y': 0},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 8553,
#   'table_len': 779},
#  {'object_type': 'Consumable',
#   'name': 'cry-Semicolon',
#   'set': 'Code',
#   'key': 'semicolon',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'code',
#   'loc_txt': {'name': ';//',
#    'text': ['Ends current non-Boss {C:cry_code}Blind{}',
#     '{C:cry_code}without{} cashing out']},
#   'rarity': '',
#   'cost': '4',
#   'pos': {'x': 0, 'y': 1},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 9352,
#   'table_len': 932},
#  {'object_type': 'Consumable',
#   'name': 'cry-Malware',
#   'set': 'Code',
#   'key': 'malware',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'code',
#   'loc_txt': {'name': '://MALWARE',
#    'text': ['Add {C:dark_edition}Glitched{} to all',
#     'cards {C:cry_code}held in hand']},
#   'rarity': '',
#   'cost': '4',
#   'pos': {'x': 1, 'y': 1},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 10302,
#   'table_len': 1438},
#  {'object_type': 'Consumable',
#   'name': 'cry-Seed',
#   'set': 'Code',
#   'key': 'seed',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'code',
#   'loc_txt': {'name': '://SEED',
#    'text': ['Select a Joker',
#     'or playing card',
#     'to become {C:cry_code}Rigged']},
#   'rarity': '',
#   'cost': '4',
#   'pos': {'x': 3, 'y': 1},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 11755,
#   'table_len': 1500},
#  {'object_type': 'Consumable',
#   'name': 'cry-Hook',
#   'set': 'Code',
#   'key': 'hook',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'code',
#   'loc_txt': {'name': 'HOOK://',
#    'text': ['Select two Jokers', 'to become {C:cry_code}Hooked']},
#   'rarity': '',
#   'cost': '4',
#   'pos': {'x': 0, 'y': 4},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 13902,
#   'table_len': 893},
#  {'object_type': 'Consumable',
#   'name': 'cry-Variable',
#   'set': 'Code',
#   'key': 'variable',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'code',
#   'loc_txt': {'name': '://VARIABLE',
#    'text': ['Convert {C:cry_code}#1#{} selected cards',
#     'to a {C:cry_code}chosen{} rank']},
#   'rarity': '',
#   'cost': '4',
#   'pos': {'x': 2, 'y': 1},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 15999,
#   'table_len': 984},
#  {'object_type': 'Consumable',
#   'name': 'cry-Class',
#   'set': 'Code',
#   'key': 'class',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'code',
#   'loc_txt': {'name': '://CLASS',
#    'text': ['Convert {C:cry_code}#1#{} selected card',
#     'to a {C:cry_code}chosen{} enhancement']},
#   'rarity': '',
#   'cost': '4',
#   'pos': {'x': 4, 'y': 1},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 16998,
#   'table_len': 974},
#  {'object_type': 'Consumable',
#   'name': 'cry-Commit',
#   'set': 'Code',
#   'key': 'commit',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'code',
#   'loc_txt': {'name': '://COMMIT',
#    'text': ['Destroy a {C:cry_code}selected{} Joker,',
#     'create a {C:cry_code}new{} Joker',
#     'of the {C:cry_code}same rarity']},
#   'rarity': '0',
#   'cost': '4',
#   'pos': {'x': 1, 'y': 2},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 17988,
#   'table_len': 2014},
#  {'object_type': 'Consumable',
#   'name': 'cry-Merge',
#   'set': 'Code',
#   'key': 'merge',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'code',
#   'loc_txt': {'name': '://MERGE',
#    'text': ['Merge a selected {C:cry_code}consumable',
#     'with a selected {C:cry_code}playing card']},
#   'rarity': '',
#   'cost': '4',
#   'pos': {'x': 0, 'y': 2},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 20017,
#   'table_len': 2777},
#  {'object_type': 'Consumable',
#   'name': 'cry-Multiply',
#   'set': 'Code',
#   'key': 'multiply',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'code',
#   'loc_txt': {'name': '://MULTIPLY',
#    'text': ['{C:cry_code}Double{} all values of',
#     'a selected {C:cry_code}Joker{} until',
#     'end of round']},
#   'rarity': '',
#   'cost': '4',
#   'pos': {'x': 3, 'y': 2},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 22812,
#   'table_len': 946},
#  {'object_type': 'Consumable',
#   'name': 'cry-Divide',
#   'set': 'Code',
#   'key': 'divide',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'code',
#   'loc_txt': {'name': '://DIVIDE',
#    'text': ['{C:cry_code}Halve{} all listed prices', 'in current shop']},
#   'rarity': '',
#   'cost': '4',
#   'pos': {'x': 2, 'y': 2},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 23774,
#   'table_len': 1061},
#  {'object_type': 'Consumable',
#   'name': 'cry-Delete',
#   'set': 'Code',
#   'key': 'delete',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'code',
#   'loc_txt': {'name': '://DELETE',
#    'text': ['{C:cry_code}Permanently{} remove a',
#     '{C:cry_code}selected{} shop item',
#     '{C:inactive,s:0.8}Item cannot appear again this run']},
#   'rarity': '',
#   'cost': '4',
#   'pos': {'x': 4, 'y': 2},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 24851,
#   'table_len': 1853},
#  {'object_type': 'Consumable',
#   'name': 'cry-Spaghetti',
#   'set': 'Code',
#   'key': 'spaghetti',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'code',
#   'loc_txt': {'name': '://SPAGHETTI',
#    'text': ['Create a {C:cry_code}Glitched', 'Food Joker']},
#   'rarity': '',
#   'cost': '4',
#   'pos': {'x': 5, 'y': 2},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 26723,
#   'table_len': 3597},
#  {'object_type': 'Consumable',
#   'name': 'cry-Machine Code',
#   'set': 'Code',
#   'key': 'machinecode',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'code',
#   'loc_txt': {'name': '://MACHINECODE', 'text': ['']},
#   'rarity': '',
#   'cost': '3',
#   'pos': {'x': 0, 'y': 3},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 30341,
#   'table_len': 625},
#  {'object_type': 'Consumable',
#   'name': 'cry-Run',
#   'set': 'Code',
#   'key': 'run',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'code',
#   'loc_txt': {'name': '://RUN',
#    'text': ['Visit a {C:cry_code}shop', 'during a {C:cry_code}Blind']},
#   'rarity': '',
#   'cost': '3',
#   'pos': {'x': 5, 'y': 0},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 30979,
#   'table_len': 1319},
#  {'object_type': 'Consumable',
#   'name': 'cry-Exploit',
#   'set': 'Code',
#   'key': 'exploit',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'code',
#   'loc_txt': {'name': '://EXPLOIT',
#    'text': ['The {C:cry_code}next{} hand played',
#     'is calculated as a',
#     '{C:cry_code}chosen{} poker hand',
#     '{C:inactive,s:0.8}Secret hands must be',
#     '{C:inactive,s:0.8}discovered to be valid']},
#   'rarity': '',
#   'cost': '4',
#   'pos': {'x': 1, 'y': 3},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 32315,
#   'table_len': 1103},
#  {'object_type': 'Consumable',
#   'name': 'cry-oboe',
#   'set': 'Code',
#   'key': 'oboe',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'code',
#   'loc_txt': {'name': '://OFFBYONE',
#    'text': ['Next {C:cry_code}Booster Pack{} has',
#     '{C:cry_code}#1#{} extra card and',
#     '{C:cry_code}#1#{} extra choice',
#     '{C:inactive}(Currently {C:cry_code}+#2#{C:inactive})']},
#   'rarity': '',
#   'cost': '4',
#   'pos': {'x': 2, 'y': 3},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 33432,
#   'table_len': 833},
#  {'object_type': 'Consumable',
#   'name': 'cry-Rework',
#   'set': 'Code',
#   'key': 'rework',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'code',
#   'loc_txt': {'name': '://REWORK',
#    'text': ['Destroy a {C:cry_code}selected{} Joker,',
#     'create a {C:cry_code}Rework Tag{} with',
#     'an {C:cry_code}upgraded{} edition',
#     '{C:inactive,s:0.8}Upgrades using order in the Collection']},
#   'rarity': '',
#   'cost': '4',
#   'pos': {'x': 3, 'y': 3},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 34281,
#   'table_len': 1824},
#  {'object_type': 'Tag',
#   'name': 'cry-Rework Tag',
#   'set': '',
#   'key': 'rework',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'tag_cry',
#   'loc_txt': {'name': 'Rework Tag',
#    'text': ['Shop has a(n)', '{C:dark_edition}#1# {C:cry_code}#2#']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 3},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 36125,
#   'table_len': 1197},
#  {'object_type': 'Consumable',
#   'name': 'cry-Automaton',
#   'set': 'Tarot',
#   'key': 'automaton',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'code',
#   'loc_txt': {'name': 'The Automaton',
#    'text': ['Creates up to {C:attention}#1#',
#     'random {C:cry_code}Code{} card',
#     '{C:inactive}(Must have room)']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 5, 'y': 1},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 37342,
#   'table_len': 1352},
#  {'object_type': 'Seal',
#   'name': 'cry-Green-Seal',
#   'set': '',
#   'key': 'green',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'green_atlas',
#   'loc_txt': {'name': 'Green Seal',
#    'text': ['Creates a {C:cry_code}Code{} card',
#     'when played and unscoring',
#     '{C:inactive}(Must have room)']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 0},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 38715,
#   'table_len': 1142},
#  {'object_type': 'Consumable',
#   'name': 'cry-Source',
#   'set': 'Spectral',
#   'key': 'source',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasnotjokers',
#   'loc_txt': {'name': 'Source',
#    'text': ['Add a {C:cry_code}Green Seal{}',
#     'to {C:attention}#1#{} selected',
#     'card in your hand']},
#   'rarity': '',
#   'cost': '4',
#   'pos': {'x': 2, 'y': 4},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 40016,
#   'table_len': 1514},
#  {'object_type': 'Consumable',
#   'name': 'cry-Pointer',
#   'set': 'Spectral',
#   'key': 'pointer',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'code',
#   'loc_txt': {'name': 'POINTER://',
#    'text': ['Create a card',
#     'of {C:cry_code}your choice',
#     '{C:inactive,s:0.8}(Exotic Jokers #1#excluded)']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 4, 'y': 3},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 41547,
#   'table_len': 1103},
#  {'object_type': 'Back',
#   'name': 'cry-Encoded',
#   'set': '',
#   'key': 'encoded',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasdeck',
#   'loc_txt': {'name': 'Encoded Deck',
#    'text': ['Start with a {C:cry_code,T:j_cry_CodeJoker}Code Joker{}',
#     'and a {C:cry_code,T:j_cry_copypaste}Copy/Paste{}',
#     'Only {C:cry_code}Code Cards{} appear in shop']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 2, 'y': 5},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 42668,
#   'table_len': 465},
#  {'object_type': 'Back',
#   'name': 'cry-Source Deck',
#   'set': '',
#   'key': 'source_deck',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasenhanced',
#   'loc_txt': {'name': 'Source Deck',
#    'text': ['All cards have a {C:cry_code}Green Seal{}',
#     'Cards cannot change seals']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 3, 'y': 5},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 43155,
#   'table_len': 346},
#  {'object_type': 'Joker',
#   'name': 'cry-CodeJoker',
#   'set': 'Edition',
#   'key': 'CodeJoker',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasepic',
#   'loc_txt': {'name': 'Code Joker',
#    'text': ['Create a {C:dark_edition}Negative{}',
#     '{C:cry_code}Code Card{} when',
#     '{C:attention}Blind{} is selected']},
#   'rarity': '',
#   'cost': '11',
#   'pos': {'x': 2, 'y': 4},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 43522,
#   'table_len': 914},
#  {'object_type': 'Joker',
#   'name': 'cry-copypaste',
#   'set': '',
#   'key': 'copypaste',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasepic',
#   'loc_txt': {'name': 'Copy/Paste',
#    'text': ['When a {C:cry_code}Code{} card is used,',
#     '{C:green}#1# in #2#{} chance to add a copy',
#     'to your consumable area',
#     '{C:inactive}(Must have room)']},
#   'rarity': '',
#   'cost': '14',
#   'pos': {'x': 3, 'y': 4},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 44456,
#   'table_len': 2099},
#  {'object_type': 'Joker',
#   'name': 'cry-cut',
#   'set': '',
#   'key': 'cut',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasthree',
#   'loc_txt': {'name': 'Cut',
#    'text': ['This Joker destroys',
#     'a random {C:cry_code}Code{} card',
#     'and gains {X:mult,C:white} X#1# {} Mult',
#     'at the end of the {C:attention}shop{}',
#     '{C:inactive}(Currently {X:mult,C:white} X#2# {C:inactive} Mult)']},
#   'rarity': '3',
#   'cost': '7',
#   'pos': {'x': 2, 'y': 2},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 47040,
#   'table_len': 2484},
#  {'object_type': 'Joker',
#   'name': 'cry-blender',
#   'set': '',
#   'key': 'blender',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasthree',
#   'loc_txt': {'name': 'Blender',
#    'text': ['Create a {C:attention}random{}',
#     'consumable when a',
#     '{C:cry_code}Code{} card is used',
#     '{C:inactive}(Must have room){}']},
#   'rarity': '1',
#   'cost': '5',
#   'pos': {'x': 3, 'y': 2},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 49897,
#   'table_len': 925},
#  {'object_type': 'Joker',
#   'name': 'cry-python',
#   'set': '',
#   'key': 'python',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasthree',
#   'loc_txt': {'name': 'Python',
#    'text': ['This Joker gains',
#     '{X:mult,C:white} X#1# {} Mult when a',
#     '{C:cry_code}Code{} card is used',
#     '{C:inactive}(Currently {X:mult,C:white} X#2# {C:inactive} Mult)']},
#   'rarity': '2',
#   'cost': '7',
#   'pos': {'x': 4, 'y': 2},
#   'file_name': 'cryptid\\Items\\CodeCards.lua',
#   'table_begin_idx': 50839,
#   'table_len': 1591},
#  {'object_type': 'Back',
#   'name': 'Very Fair Deck',
#   'set': '',
#   'key': 'very_fair',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasdeck',
#   'loc_txt': {'name': 'Very Fair Deck',
#    'text': ['{C:blue}-2{} hands, {C:red}-2{} discards',
#     'every round',
#     '{C:attention}Vouchers{} no longer',
#     'appear in the shop']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 4, 'y': 0},
#   'file_name': 'cryptid\\Items\\Decks.lua',
#   'table_begin_idx': 273,
#   'table_len': 623},
#  {'object_type': 'Back',
#   'name': 'cry-Equilibrium',
#   'set': '',
#   'key': 'equilibrium',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasdeck',
#   'loc_txt': {'name': 'Deck of Equilibrium',
#    'text': ['All cards have the',
#     '{C:attention}same chance{} of',
#     'appearing in shops,',
#     'start run with',
#     '{C:attention,T:v_overstock_plus}Overstock Plus']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 1},
#   'file_name': 'cryptid\\Items\\Decks.lua',
#   'table_begin_idx': 5638,
#   'table_len': 509},
#  {'object_type': 'Back',
#   'name': 'cry-Misprint',
#   'set': '',
#   'key': 'misprint',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasdeck',
#   'loc_txt': {'name': 'Misprint Deck',
#    'text': ['Values of cards',
#     'and poker hands',
#     'are {C:attention}randomized']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 4, 'y': 2},
#   'file_name': 'cryptid\\Items\\Decks.lua',
#   'table_begin_idx': 6165,
#   'table_len': 367},
#  {'object_type': 'Back',
#   'name': 'cry-Infinite',
#   'set': '',
#   'key': 'infinite',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasdeck',
#   'loc_txt': {'name': 'Infinite Deck',
#    'text': ['You can select {C:attention}any',
#     'number of cards',
#     '{C:attention}+1{} hand size']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 3, 'y': 0},
#   'file_name': 'cryptid\\Items\\Decks.lua',
#   'table_begin_idx': 6550,
#   'table_len': 384},
#  {'object_type': 'Back',
#   'name': 'cry-Conveyor',
#   'set': '',
#   'key': 'conveyor',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasdeck',
#   'loc_txt': {'name': 'Conveyor Deck',
#    'text': ['Jokers may {C:attention}not{} be moved',
#     'At start of round,',
#     '{C:attention}duplicate{} rightmost Joker',
#     'and {C:attention}destroy{} leftmost Joker']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 1, 'y': 1},
#   'file_name': 'cryptid\\Items\\Decks.lua',
#   'table_begin_idx': 6952,
#   'table_len': 446},
#  {'object_type': 'Back',
#   'name': 'cry-CCD',
#   'set': '',
#   'key': 'CCD',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasdeck',
#   'loc_txt': {'name': 'CCD Deck',
#    'text': ['Every card is also', 'a {C:attention}random{} consumable']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 0},
#   'file_name': 'cryptid\\Items\\Decks.lua',
#   'table_begin_idx': 7411,
#   'table_len': 309},
#  {'object_type': 'Back',
#   'name': 'cry-Wormhole',
#   'set': '',
#   'key': 'wormhole',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasdeck',
#   'loc_txt': {'name': 'Wormhole Deck',
#    'text': ['Start with an {C:cry_exotic}Exotic{C:attention} Joker',
#     'Jokers are {C:attention}20X{} more',
#     'likely to be {C:dark_edition}Negative',
#     '{C:attention}-2{} Joker slots']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 3, 'y': 4},
#   'file_name': 'cryptid\\Items\\Decks.lua',
#   'table_begin_idx': 7738,
#   'table_len': 503},
#  {'object_type': 'Back',
#   'name': 'cry-Redeemed',
#   'set': '',
#   'key': 'redeemed',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasdeck',
#   'loc_txt': {'name': 'Redeemed Deck',
#    'text': ['When a {C:attention}Voucher{} is purchased,',
#     'gain its {C:attention}extra tiers']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 4, 'y': 4},
#   'file_name': 'cryptid\\Items\\Decks.lua',
#   'table_begin_idx': 8259,
#   'table_len': 353},
#  {'object_type': 'Back',
#   'name': 'cry-Critical',
#   'set': '',
#   'key': 'critical',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasdeck',
#   'loc_txt': {'name': 'Critical Deck',
#    'text': ['After each hand played,',
#     '{C:green}#1# in 4{} chance for {X:dark_edition,C:white} ^2 {} Mult',
#     '{C:green}#1# in 8{} chance for {X:dark_edition,C:white} ^0.5 {} Mult']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 4, 'y': 5},
#   'file_name': 'cryptid\\Items\\Decks.lua',
#   'table_begin_idx': 8630,
#   'table_len': 2055},
#  {'object_type': 'Back',
#   'name': 'cry-Glowing',
#   'set': '',
#   'key': 'glowing',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'glowing',
#   'loc_txt': {'name': 'Glowing Deck',
#    'text': ['Multiply the values of',
#     'all Jokers by {X:dark_edition,C:white} X1.25 {}',
#     'when Boss Blind is defeated',
#     '{X:cry_jolly,C:white,s:0.8} Jolly#1#Open#1#Winner#1#-#1#wawa#1#person']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 4, 'y': 2},
#   'file_name': 'cryptid\\Items\\Decks.lua',
#   'table_begin_idx': 10702,
#   'table_len': 1050},
#  {'object_type': 'Joker',
#   'name': 'cry-supercell',
#   'set': '',
#   'key': 'supercell',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasepic',
#   'loc_txt': {'name': 'Supercell',
#    'text': ['{C:chips}+#1#{} Chips, {C:mult}+#1#{} Mult,',
#     '{X:chips,C:white}X#2#{} Chips, {X:mult,C:white}X#2#{} Mult',
#     'Earn {C:money}$#3#{} at',
#     'end of round']},
#   'rarity': '',
#   'cost': '14',
#   'pos': {'x': 5, 'y': 1},
#   'file_name': 'cryptid\\Items\\EpicJokers.lua',
#   'table_begin_idx': 18,
#   'table_len': 1358},
#  {'object_type': 'Joker',
#   'name': 'cry-Googol Play Card',
#   'set': '',
#   'key': 'googol_play',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasepic',
#   'loc_txt': {'name': 'Googol Play Card',
#    'text': ['{C:green}#1# in #2#{} chance for',
#     '{X:red,C:white} X#3# {} Mult']},
#   'rarity': '',
#   'cost': '10',
#   'pos': {'x': 3, 'y': 0},
#   'file_name': 'cryptid\\Items\\EpicJokers.lua',
#   'table_begin_idx': 4160,
#   'table_len': 1021},
#  {'object_type': 'Joker',
#   'name': 'cry-Sync Catalyst',
#   'set': '',
#   'key': 'sync_catalyst',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasepic',
#   'loc_txt': {'name': 'Sync Catalyst',
#    'text': ['Balances {C:chips}Chips{} and {C:mult}Mult{}',
#     '{C:inactive,s:0.8}Hey! I"ve seen this one before!']},
#   'rarity': '',
#   'cost': '12',
#   'pos': {'x': 5, 'y': 2},
#   'file_name': 'cryptid\\Items\\EpicJokers.lua',
#   'table_begin_idx': 5836,
#   'table_len': 1022},
#  {'object_type': 'Joker',
#   'name': 'cry-Negative Joker',
#   'set': '',
#   'key': 'negative',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasepic',
#   'loc_txt': {'name': 'Negative Joker',
#    'text': ['{C:dark_edition}+#1#{C:attention} Joker{} slots']},
#   'rarity': '',
#   'cost': '10',
#   'pos': {'x': 1, 'y': 3},
#   'file_name': 'cryptid\\Items\\EpicJokers.lua',
#   'table_begin_idx': 6876,
#   'table_len': 671},
#  {'object_type': 'Joker',
#   'name': 'cry-Canvas',
#   'set': '',
#   'key': 'canvas',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasepic',
#   'loc_txt': {'name': 'Canvas',
#    'text': ['{C:attention}Retrigger{} all {C:attention}Jokers{} to the left',
#     'once for {C:attention}every{} non-{C:blue}Common{C:attention} Joker{}',
#     'to the right of this Joker']},
#   'rarity': '',
#   'cost': '18',
#   'pos': {'x': 2, 'y': 1},
#   'file_name': 'cryptid\\Items\\EpicJokers.lua',
#   'table_begin_idx': 7563,
#   'table_len': 1067},
#  {'object_type': 'Joker',
#   'name': 'cry-Error',
#   'set': '',
#   'key': 'error',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasepic',
#   'loc_txt': {'name': '{C:red}ERR{}{C:dark_edition}O{}{C:red}R{}',
#    'text': ['']},
#   'rarity': '',
#   'cost': '1',
#   'pos': {'x': 4, 'y': 2},
#   'file_name': 'cryptid\\Items\\EpicJokers.lua',
#   'table_begin_idx': 9426,
#   'table_len': 2359},
#  {'object_type': 'Joker',
#   'name': 'cry-m',
#   'set': 'Joker',
#   'key': 'm',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasepic',
#   'loc_txt': {'name': 'm',
#    'text': ['This Joker gains {X:mult,C:white} X#1# {} Mult',
#     'when {C:attention}Jolly Joker{} is sold',
#     '{C:inactive}(Currently {X:mult,C:white} X#2# {C:inactive} Mult)']},
#   'rarity': '',
#   'cost': '13',
#   'pos': {'x': 3, 'y': 1},
#   'file_name': 'cryptid\\Items\\EpicJokers.lua',
#   'table_begin_idx': 12571,
#   'table_len': 1622},
#  {'object_type': 'Joker',
#   'name': 'cry-M',
#   'set': 'Joker',
#   'key': 'M',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasepic',
#   'loc_txt': {'name': 'M',
#    'text': ['Create a {C:dark_edition}Negative{}',
#     '{C:attention}Jolly Joker{} when',
#     '{C:attention}Blind{} is selected']},
#   'rarity': '',
#   'cost': '13',
#   'pos': {'x': 0, 'y': 0},
#   'file_name': 'cryptid\\Items\\EpicJokers.lua',
#   'table_begin_idx': 14426,
#   'table_len': 1102},
#  {'object_type': 'Joker',
#   'name': 'cry-Boredom',
#   'set': '',
#   'key': 'boredom',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasepic',
#   'loc_txt': {'name': 'Boredom',
#    'text': ['{C:green}#1# in #2#{} chance to',
#     '{C:attention}retrigger{} each {C:attention}Joker{}',
#     'or {C:attention}played card{}',
#     '{C:inactive,s:0.8}Does not affect other Boredom{}']},
#   'rarity': '',
#   'cost': '14',
#   'pos': {'x': 1, 'y': 0},
#   'file_name': 'cryptid\\Items\\EpicJokers.lua',
#   'table_begin_idx': 15546,
#   'table_len': 1289},
#  {'object_type': 'Joker',
#   'name': 'cry-Number Blocks',
#   'set': '',
#   'key': 'number_blocks',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasepic',
#   'loc_txt': {'name': 'Number Blocks',
#    'text': ['Earn {C:money}$#1#{} at end of round',
#     'Increase payout by {C:money}$#2#{}',
#     'for each {C:attention}#3#{} held in hand,',
#     'rank changes every round']},
#   'rarity': '',
#   'cost': '14',
#   'pos': {'x': 0, 'y': 2},
#   'file_name': 'cryptid\\Items\\EpicJokers.lua',
#   'table_begin_idx': 17325,
#   'table_len': 1701},
#  {'object_type': 'Joker',
#   'name': 'cry-Double Scale',
#   'set': '',
#   'key': 'Double Scale',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasepic',
#   'loc_txt': {'name': 'Double Scale',
#    'text': ['Scaling {C:attention}Jokers{}',
#     'scale {C:attention}quadratically',
#     '{C:inactive,s:0.8}(ex. +1, +3, +6, +10)',
#     '{C:inactive,s:0.8}(grows by +1, +2, +3)']},
#   'rarity': '',
#   'cost': '18',
#   'pos': {'x': 0, 'y': 3},
#   'file_name': 'cryptid\\Items\\EpicJokers.lua',
#   'table_begin_idx': 19752,
#   'table_len': 671},
#  {'object_type': 'Joker',
#   'name': 'cry_oldcandy',
#   'set': '',
#   'key': 'oldcandy',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasepic',
#   'loc_txt': {'name': 'Nostalgic Candy',
#    'text': ['Sell this card to',
#     'permanently gain',
#     '{C:attention}+#1#{} hand size']},
#   'rarity': '',
#   'cost': '9',
#   'pos': {'x': 4, 'y': 1},
#   'file_name': 'cryptid\\Items\\EpicJokers.lua',
#   'table_begin_idx': 20441,
#   'table_len': 713},
#  {'object_type': 'Joker',
#   'name': 'cry-circus',
#   'set': '',
#   'key': 'circus',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasepic',
#   'loc_txt': {'name': 'Circus',
#    'text': ['{C:red}Rare{} Jokers each give {X:mult,C:white} X#1# {} Mult',
#     '{C:cry_epic}Epic{} Jokers each give {X:mult,C:white} X#2# {} Mult',
#     '{C:legendary}Legendary{} Jokers each give {X:mult,C:white} X#3# {} Mult',
#     '{C:cry_exotic}Exotic{} Jokers each give {X:mult,C:white} X#4# {} Mult']},
#   'rarity': '',
#   'cost': '16',
#   'pos': {'x': 4, 'y': 4},
#   'file_name': 'cryptid\\Items\\EpicJokers.lua',
#   'table_begin_idx': 21379,
#   'table_len': 3409},
#  {'object_type': 'Joker',
#   'name': 'cry-caramel',
#   'set': '',
#   'key': 'caramel',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasepic',
#   'loc_txt': {'name': 'Caramel',
#    'text': ['Each played card gives',
#     '{X:mult,C:white}X#1#{} Mult when scored',
#     'for the next {C:attention}#2#{} rounds']},
#   'rarity': '',
#   'cost': '12',
#   'pos': {'x': 0, 'y': 1},
#   'file_name': 'cryptid\\Items\\EpicJokers.lua',
#   'table_begin_idx': 24828,
#   'table_len': 2318},
#  {'object_type': 'Joker',
#   'name': 'cry_curse',
#   'set': '',
#   'key': 'curse',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasepic',
#   'loc_txt': {'name': 'Sob',
#    'text': ['{C:edition,E:1}you cannot{} {C:cry_ascendant,E:1}run...{}',
#     '{C:edition,E:1}you cannot{} {C:cry_ascendant,E:1}hide...{}',
#     '{C:dark_edition,E:1}you cannot escape...{}',
#     '{C:inactive}(Must have room){}']},
#   'rarity': '',
#   'cost': '9',
#   'pos': {'x': 1, 'y': 1},
#   'file_name': 'cryptid\\Items\\EpicJokers.lua',
#   'table_begin_idx': 28234,
#   'table_len': 10195},
#  {'object_type': 'Joker',
#   'name': 'cry-bonusjoker',
#   'set': '',
#   'key': 'bonusjoker',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasepic',
#   'loc_txt': {'name': 'Bonus Joker',
#    'text': ['{C:green}#1# in #2#{} chance for each',
#     'played {C:attention}Bonus{} card to increase',
#     '{C:attention}Joker{} or {C:attention}Consumable slots',
#     'by {C:dark_edition}1{} when scored',
#     '{C:red}Works twice per round',
#     '{C:inactive,s:0.8}(Equal chance for each){}']},
#   'rarity': '',
#   'cost': '11',
#   'pos': {'x': 3, 'y': 2},
#   'file_name': 'cryptid\\Items\\EpicJokers.lua',
#   'table_begin_idx': 38604,
#   'table_len': 2151},
#  {'object_type': 'Joker',
#   'name': 'cry-multjoker',
#   'set': '',
#   'key': 'multjoker',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasepic',
#   'loc_txt': {'name': 'Mult Joker',
#    'text': ['{C:green}#1# in #2#{} chance for each',
#     'played {C:attention}Mult{} card to create',
#     'a {C:spectral}Cryptid{} card when scored',
#     '{C:inactive}(Must have room)']},
#   'rarity': '',
#   'cost': '11',
#   'pos': {'x': 2, 'y': 3},
#   'file_name': 'cryptid\\Items\\EpicJokers.lua',
#   'table_begin_idx': 42140,
#   'table_len': 2022},
#  {'object_type': 'Joker',
#   'name': 'cry-goldjoker',
#   'set': '',
#   'key': 'goldjoker',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasepic',
#   'loc_txt': {'name': 'Gold Joker',
#    'text': ['Earn {C:money}#1#%{} of total',
#     'money at end of round',
#     'Payout increases by {C:money}#2#%{}',
#     'when each played {C:attention}Gold{}',
#     'card is scored']},
#   'rarity': '',
#   'cost': '14',
#   'pos': {'x': 0, 'y': 4},
#   'file_name': 'cryptid\\Items\\EpicJokers.lua',
#   'table_begin_idx': 45540,
#   'table_len': 1710},
#  {'object_type': 'Joker',
#   'name': 'cry-altgoogol',
#   'set': '',
#   'key': 'altgoogol',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasepic',
#   'loc_txt': {'name': 'Nostalgic Googol Play Card',
#    'text': ['Sell this card to create',
#     '{C:attention}2{} copies of the leftmost {C:attention}Joker{}',
#     '{C:inactive,s:0.8}Does not copy Nostalgic Googol Play Cards{}']},
#   'rarity': '',
#   'cost': '10',
#   'pos': {'x': 4, 'y': 3},
#   'file_name': 'cryptid\\Items\\EpicJokers.lua',
#   'table_begin_idx': 47981,
#   'table_len': 1429},
#  {'object_type': 'Consumable',
#   'name': 'cry-Gateway',
#   'set': 'Spectral',
#   'key': 'gateway',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'gateway',
#   'loc_txt': {'name': 'Gateway',
#    'text': ['Create a random',
#     '{C:cry_exotic,E:1}Exotic{C:attention} Joker{}, destroy',
#     'all other Jokers']},
#   'rarity': '',
#   'cost': '4',
#   'pos': {'x': 0, 'y': 0},
#   'file_name': 'cryptid\\Items\\Exotic.lua',
#   'table_begin_idx': 439,
#   'table_len': 1531},
#  {'object_type': 'Joker',
#   'name': 'cry-Iterum',
#   'set': '',
#   'key': 'iterum',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasexotic',
#   'loc_txt': {'name': 'Iterum',
#    'text': ['Retrigger all cards played',
#     '{C:attention}#2#{} time(s),',
#     'each played card gives',
#     '{X:mult,C:white} X#1# {} Mult when scored']},
#   'rarity': '',
#   'cost': '50',
#   'pos': {'x': 0, 'y': 1},
#   'file_name': 'cryptid\\Items\\Exotic.lua',
#   'table_begin_idx': 2118,
#   'table_len': 1276},
#  {'object_type': 'Joker',
#   'name': 'cry-Universum',
#   'set': '',
#   'key': 'universum',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasexotic',
#   'loc_txt': {'name': 'Universum',
#    'text': ['{C:attention}Poker hands{} gain',
#     '{X:red,C:white} X#1# {} Mult and {X:blue,C:white} X#1# {} Chips',
#     'when leveled up']},
#   'rarity': '',
#   'cost': '50',
#   'pos': {'x': 3, 'y': 3},
#   'file_name': 'cryptid\\Items\\Exotic.lua',
#   'table_begin_idx': 4582,
#   'table_len': 746},
#  {'object_type': 'Joker',
#   'name': 'cry-Exponentia',
#   'set': '',
#   'key': 'exponentia',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasexotic',
#   'loc_txt': {'name': 'Exponentia',
#    'text': ['This Joker gains {X:dark_edition,C:white} ^#1# {} Mult',
#     'when {X:red,C:white} XMult {} is triggered',
#     '{C:inactive}(Currently {X:dark_edition,C:white} ^#2# {C:inactive} Mult)']},
#   'rarity': '',
#   'cost': '50',
#   'pos': {'x': 0, 'y': 0},
#   'file_name': 'cryptid\\Items\\Exotic.lua',
#   'table_begin_idx': 5348,
#   'table_len': 1140},
#  {'object_type': 'Joker',
#   'name': 'cry-Speculo',
#   'set': '',
#   'key': 'speculo',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasexotic',
#   'loc_txt': {'name': 'Speculo',
#    'text': ['Creates a {C:dark_edition}Negative{} copy',
#     'of a random {C:attention}Joker{}',
#     'at the end of the {C:attention}shop',
#     '{C:inactive,s:0.8}Does not copy other Speculo{}']},
#   'rarity': '',
#   'cost': '50',
#   'pos': {'x': 3, 'y': 1},
#   'file_name': 'cryptid\\Items\\Exotic.lua',
#   'table_begin_idx': 7238,
#   'table_len': 1723},
#  {'object_type': 'Joker',
#   'name': 'cry-Redeo',
#   'set': '',
#   'key': 'redeo',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasexotic',
#   'loc_txt': {'name': 'Redeo',
#    'text': ['{C:attention}-#1#{} Ante when',
#     '{C:money}$#2#{} {C:inactive}($#3#){} spent',
#     '{s:0.8}Requirements increase',
#     '{C:attention,s:0.8}exponentially{s:0.8} per use',
#     '{C:money,s:0.8}Next increase: {s:1,c:money}$#4#']},
#   'rarity': '',
#   'cost': '50',
#   'pos': {'x': 3, 'y': 0},
#   'file_name': 'cryptid\\Items\\Exotic.lua',
#   'table_begin_idx': 8976,
#   'table_len': 1794},
#  {'object_type': 'Joker',
#   'name': 'cry-Tenebris',
#   'set': '',
#   'key': 'tenebris',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasexotic',
#   'loc_txt': {'name': 'Tenebris',
#    'text': ['{C:dark_edition}+#1#{C:attention} Joker{} slots',
#     'Earn {C:money}$#2#{} at end of round']},
#   'rarity': '',
#   'cost': '50',
#   'pos': {'x': 3, 'y': 2},
#   'file_name': 'cryptid\\Items\\Exotic.lua',
#   'table_begin_idx': 11137,
#   'table_len': 910},
#  {'object_type': 'Joker',
#   'name': 'cry-Effarcire',
#   'set': '',
#   'key': 'effarcire',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'effarcire',
#   'loc_txt': {'name': 'Effarcire',
#    'text': ['Draw {C:green}full deck{} to hand',
#     'when {C:attention}Blind{} is selected',
#     "{C:inactive,s:0.8}If you can't handle me at my 1x,",
#     "{C:inactive,s:0.8}you don't deserve me at my 2x"]},
#   'rarity': '',
#   'cost': '50',
#   'pos': {'x': 0, 'y': 0},
#   'file_name': 'cryptid\\Items\\Exotic.lua',
#   'table_begin_idx': 12576,
#   'table_len': 784},
#  {'object_type': 'Joker',
#   'name': 'cry-crustulum',
#   'set': '',
#   'key': 'crustulum',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasexotic',
#   'loc_txt': {'name': 'Crustulum',
#    'text': ['This Joker gains {C:chips}+#2#{} Chips',
#     'per {C:attention}reroll{} in the shop',
#     '{C:green}All rerolls are free{}',
#     '{C:inactive}(Currently {C:chips}+#1#{C:inactive} chips)']},
#   'rarity': '',
#   'cost': '50',
#   'pos': {'x': 0, 'y': 2},
#   'file_name': 'cryptid\\Items\\Exotic.lua',
#   'table_begin_idx': 13507,
#   'table_len': 1543},
#  {'object_type': 'Joker',
#   'name': 'cry-primus',
#   'set': '',
#   'key': 'primus',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasexotic',
#   'loc_txt': {'name': 'Primus',
#    'text': ['This Joker gains {X:dark_edition,C:white} ^#1# {} Mult',
#     'if all cards in played hand are',
#     '{C:attention}Aces{}, {C:attention}2s{}, {C:attention}3s{}, {C:attention}5s{}, or {C:attention}7s{}',
#     '{C:inactive}(Currently {X:dark_edition,C:white} ^#2# {C:inactive} Mult)']},
#   'rarity': '',
#   'cost': '53',
#   'pos': {'x': 0, 'y': 4},
#   'file_name': 'cryptid\\Items\\Exotic.lua',
# ...
#   'table_len': 410},
#  {'object_type': 'Stake',
#   'name': 'cry-Sapphire Stake',
#   'set': '',
#   'key': 'sapphire',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'stake',
#   'loc_txt': {'name': 'Sapphire Stake',
#    'text': ['Lose {C:attention}25%{} of current money',
#     'at end of Ante',
#     '{s:0.8,C:inactive}(Up to $10){}']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 3, 'y': 2},
#   'file_name': 'cryptid\\Items\\Stakes.lua',
#   'table_begin_idx': 5663,
#   'table_len': 528},
#  {'object_type': 'Stake',
#   'name': 'cry-Emerald Stake',
#   'set': '',
#   'key': 'emerald',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'stake',
#   'loc_txt': {'name': 'Emerald Stake',
#    'text': ['Cards, packs, and vouchers',
#     'can be {C:attention}face down{}',
#     '{s:0.8,C:inactive}(Unable to be viewed until purchased){}']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 4, 'y': 2},
#   'file_name': 'cryptid\\Items\\Stakes.lua',
#   'table_begin_idx': 6208,
#   'table_len': 524},
#  {'object_type': 'Stake',
#   'name': 'cry-Platinum Stake',
#   'set': '',
#   'key': 'platinum',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'stake',
#   'loc_txt': {'name': 'Platinum Stake',
#    'text': ['Small Blinds are {C:attention}removed{}']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 3},
#   'file_name': 'cryptid\\Items\\Stakes.lua',
#   'table_begin_idx': 6750,
#   'table_len': 478},
#  {'object_type': 'Stake',
#   'name': 'cry-Twilight Stake',
#   'set': '',
#   'key': 'twilight',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'stake',
#   'loc_txt': {'name': 'Twilight Stake',
#    'text': ['Cards can be {C:attention}Banana{}',
#     '{s:0.8,C:inactive}(1 in 10 chance of being destroyed each round){}']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 1, 'y': 3},
#   'file_name': 'cryptid\\Items\\Stakes.lua',
#   'table_begin_idx': 7505,
#   'table_len': 491},
#  {'object_type': 'Stake',
#   'name': 'cry-Verdant Stake',
#   'set': '',
#   'key': 'verdant',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'stake',
#   'loc_txt': {'name': 'Verdant Stake',
#    'text': ['Required score scales', 'faster for each {C:attention}Ante']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 2, 'y': 3},
#   'file_name': 'cryptid\\Items\\Stakes.lua',
#   'table_begin_idx': 8679,
#   'table_len': 466},
#  {'object_type': 'Stake',
#   'name': 'cry-Ember Stake',
#   'set': '',
#   'key': 'ember',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'stake',
#   'loc_txt': {'name': 'Ember Stake',
#    'text': ['All items give no money when sold']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 3, 'y': 3},
#   'file_name': 'cryptid\\Items\\Stakes.lua',
#   'table_begin_idx': 9160,
#   'table_len': 403},
#  {'object_type': 'Stake',
#   'name': 'cry-Dawn Stake',
#   'set': '',
#   'key': 'dawn',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'stake',
#   'loc_txt': {'name': 'Dawn Stake',
#    'text': ['Tarots and Spectrals target {C:attention}1',
#     'fewer card',
#     '{s:0.8,C:inactive}(Minimum of 1){}']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 4, 'y': 3},
#   'file_name': 'cryptid\\Items\\Stakes.lua',
#   'table_begin_idx': 9577,
#   'table_len': 477},
#  {'object_type': 'Stake',
#   'name': 'cry-Horizon Stake',
#   'set': '',
#   'key': 'horizon',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'stake',
#   'loc_txt': {'name': 'Horizon Stake',
#    'text': ['When blind selected, add a',
#     '{C:attention}random card{} to deck']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 4},
#   'file_name': 'cryptid\\Items\\Stakes.lua',
#   'table_begin_idx': 10071,
#   'table_len': 449},
#  {'object_type': 'Stake',
#   'name': 'cry-Blossom Stake',
#   'set': '',
#   'key': 'blossom',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'stake',
#   'loc_txt': {'name': 'Blossom Stake',
#    'text': ['{C:attention}Final{} Boss Blinds can appear',
#     'in {C:attention}any{} Ante']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 1, 'y': 4},
#   'file_name': 'cryptid\\Items\\Stakes.lua',
#   'table_begin_idx': 10537,
#   'table_len': 457},
#  {'object_type': 'Stake',
#   'name': 'cry-Azure Stake',
#   'set': '',
#   'key': 'azure',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'stake',
#   'loc_txt': {'name': 'Azure Stake',
#    'text': ['Values on Jokers are reduced', 'by {C:attention}20%{}']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 2, 'y': 4},
#   'file_name': 'cryptid\\Items\\Stakes.lua',
#   'table_begin_idx': 11009,
#   'table_len': 432},
#  {'object_type': 'Stake',
#   'name': 'cry-Ascendant Stake',
#   'set': '',
#   'key': 'ascendant',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'stake',
#   'loc_txt': {'name': 'Ascendant Stake',
#    'text': ['{C:attention}-1{} Shop slot']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 3, 'y': 4},
#   'file_name': 'cryptid\\Items\\Stakes.lua',
#   'table_begin_idx': 11460,
#   'table_len': 390},
#  {'object_type': 'Voucher',
#   'name': 'Copies',
#   'set': 'Tag',
#   'key': 'copies',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasvoucher',
#   'loc_txt': {'name': 'Copies',
#    'text': ['Double Tags become',
#     '{C:attention}Triple Tags{} and are',
#     '{C:attention}2X{} as common']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 1, 'y': 1},
#   'file_name': 'cryptid\\Items\\Vouchers.lua',
#   'table_begin_idx': 150,
#   'table_len': 526},
#  {'object_type': 'Voucher',
#   'name': 'Tag Printer',
#   'set': 'Tag',
#   'key': 'tag_printer',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasvoucher',
#   'loc_txt': {'name': 'Tag Printer',
#    'text': ['Double Tags become',
#     '{C:attention}Quadruple Tags{} and',
#     'are {C:attention}3X{} as common']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 1, 'y': 2},
#   'file_name': 'cryptid\\Items\\Vouchers.lua',
#   'table_begin_idx': 697,
#   'table_len': 574},
#  {'object_type': 'Voucher',
#   'name': 'Clone Machine',
#   'set': 'Tag',
#   'key': 'clone_machine',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasvoucher',
#   'loc_txt': {'name': 'Clone Machine',
#    'text': ['Double Tags become',
#     '{C:attention}Quintuple Tags{} and',
#     'are {C:attention}4X{} as common']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 1, 'y': 3},
#   'file_name': 'cryptid\\Items\\Vouchers.lua',
#   'table_begin_idx': 1294,
#   'table_len': 583},
#  {'object_type': 'Voucher',
#   'name': 'Command Prompt',
#   'set': '',
#   'key': 'command_prompt',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasvoucher',
#   'loc_txt': {'name': 'Command Prompt',
#    'text': ['{C:cry_code}Code{} cards',
#     'can appear',
#     'in the {C:attention}shop{}']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 1},
#   'file_name': 'cryptid\\Items\\Vouchers.lua',
#   'table_begin_idx': 1901,
#   'table_len': 506},
#  {'object_type': 'Voucher',
#   'name': 'Satellite Uplink',
#   'set': '',
#   'key': 'satellite_uplink',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasvoucher',
#   'loc_txt': {'name': 'Satellite Uplink',
#    'text': ['{C:cry_code}Code{} cards may',
#     'appear in any of',
#     'the {C:attention}Celestial Packs{}']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 2},
#   'file_name': 'cryptid\\Items\\Vouchers.lua',
#   'table_begin_idx': 2433,
#   'table_len': 421},
#  {'object_type': 'Voucher',
#   'name': 'Quantum Computing',
#   'set': '',
#   'key': 'quantum_computing',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasvoucher',
#   'loc_txt': {'name': 'Quantum Computing',
#    'text': ['{C:cry_code}Code{} cards can spawn',
#     'with {C:dark_edition}Negative{} edition']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 3},
#   'file_name': 'cryptid\\Items\\Vouchers.lua',
#   'table_begin_idx': 2881,
#   'table_len': 404},
#  {'object_type': 'Voucher',
#   'name': 'Pairing',
#   'set': '',
#   'key': 'pairing',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasvoucher',
#   'loc_txt': {'name': 'Pairing',
#    'text': ['{C:attention}Retrigger{} all M Jokers',
#     'if played hand is a {C:attention}Pair']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 0},
#   'file_name': 'cryptid\\Items\\Vouchers.lua',
#   'table_begin_idx': 3302,
#   'table_len': 414},
#  {'object_type': 'Voucher',
#   'name': 'Repair Man',
#   'set': '',
#   'key': 'repair_man',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasvoucher',
#   'loc_txt': {'name': 'Repair Man',
#    'text': ['{C:attention}Retrigger{} all M Jokers',
#     'if played hand contains a {C:attention}Pair']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 1, 'y': 0},
#   'file_name': 'cryptid\\Items\\Vouchers.lua',
#   'table_begin_idx': 3736,
#   'table_len': 457},
#  {'object_type': 'Voucher',
#   'name': 'Pairamount Plus',
#   'set': '',
#   'key': 'pairamount_plus',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasvoucher',
#   'loc_txt': {'name': 'Pairamount Plus',
#    'text': ['{C:attention}Retrigger{} all M Jokers',
#     'once for every Pair',
#     '{C:attention}contained{} in played hand']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 2, 'y': 0},
#   'file_name': 'cryptid\\Items\\Vouchers.lua',
#   'table_begin_idx': 4218,
#   'table_len': 501},
#  {'object_type': 'Voucher',
#   'name': 'Multistock',
#   'set': '',
#   'key': 'overstock_multi',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasvoucher',
#   'loc_txt': {'name': 'Multistock',
#    'text': ['{C:attention}+#1#{} card slot(s) and',
#     '{C:attention}+#1#{} booster pack slot(s)',
#     'available in shop']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 4, 'y': 1},
#   'file_name': 'cryptid\\Items\\Vouchers.lua',
#   'table_begin_idx': 4744,
#   'table_len': 916},
#  {'object_type': 'Voucher',
#   'name': 'Mass Production',
#   'set': '',
#   'key': 'massproduct',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasvoucher',
#   'loc_txt': {'name': 'Mass Production',
#    'text': ['All cards and packs', 'in shop cost {C:attention}$1{}']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 6, 'y': 4},
#   'file_name': 'cryptid\\Items\\Vouchers.lua',
#   'table_begin_idx': 5681,
#   'table_len': 554},
#  {'object_type': 'Voucher',
#   'name': 'Curate',
#   'set': '',
#   'key': 'curate',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasvoucher',
#   'loc_txt': {'name': 'Curate',
#    'text': ['All cards', 'appear with', 'an {C:dark_edition}Edition{}']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 6, 'y': 1},
#   'file_name': 'cryptid\\Items\\Vouchers.lua',
#   'table_begin_idx': 6251,
#   'table_len': 275},
#  {'object_type': 'Voucher',
#   'name': 'Reroll Exchange',
#   'set': '',
#   'key': 'rerollexchange',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasvoucher',
#   'loc_txt': {'name': 'Reroll Exchange',
#    'text': ['All rerolls', 'cost {C:attention}$2{}']},
#   'rarity': '',
#   'cost': '2',
#   'pos': {'x': 6, 'y': 2},
#   'file_name': 'cryptid\\Items\\Vouchers.lua',
#   'table_begin_idx': 6550,
#   'table_len': 583},
#  {'object_type': 'Voucher',
#   'name': 'Galactic Scope',
#   'set': '',
#   'key': 'scope',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasvoucher',
#   'loc_txt': {'name': 'Galactic Scope',
#    'text': ['Create the {C:planet}Planet',
#     'card for played',
#     '{C:attention}poker hand{}',
#     '{C:inactive}(Must have room){}']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 2, 'y': 0},
#   'file_name': 'cryptid\\Items\\Vouchers.lua',
#   'table_begin_idx': 7148,
#   'table_len': 345},
#  {'object_type': 'Voucher',
#   'name': 'Dexterity',
#   'set': '',
#   'key': 'dexterity',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasvoucher',
#   'loc_txt': {'name': 'Dexterity',
#    'text': ['Permanently', 'gain {C:blue}+#1#{} hand(s)', 'each round']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 6, 'y': 3},
#   'file_name': 'cryptid\\Items\\Vouchers.lua',
#   'table_begin_idx': 7512,
#   'table_len': 724},
#  {'object_type': 'Voucher',
#   'name': 'The 3 Rs',
#   'set': '',
#   'key': 'threers',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasvoucher',
#   'loc_txt': {'name': 'The 3 Rs',
#    'text': ['Permanently', 'gain {C:red}+#1#{} discard(s)', 'each round']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 5, 'y': 0},
#   'file_name': 'cryptid\\Items\\Vouchers.lua',
#   'table_begin_idx': 8253,
#   'table_len': 726},
#  {'object_type': 'Voucher',
#   'name': 'Tarot Acclimator',
#   'set': '',
#   'key': 'tacclimator',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasvoucher',
#   'loc_txt': {'name': 'Tarot Acclimator',
#    'text': ['{C:tarot}Tarot{} cards appear',
#     '{C:attention}X#1#{} more frequently',
#     'in the shop',
#     'All future {C:tarot}Tarot{}',
#     'cards are {C:green}free{}']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 1, 'y': 4},
#   'file_name': 'cryptid\\Items\\Vouchers.lua',
#   'table_begin_idx': 9000,
#   'table_len': 744},
#  {'object_type': 'Voucher',
#   'name': 'Planet Acclimator',
#   'set': '',
#   'key': 'pacclimator',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasvoucher',
#   'loc_txt': {'name': 'Planet Acclimator',
#    'text': ['{C:planet}Planet{} cards appear',
#     '{C:attention}X#1#{} more frequently',
#     'in the shop',
#     'All future {C:planet}Planet{}',
#     'cards are {C:green}free{}']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 4},
#   'file_name': 'cryptid\\Items\\Vouchers.lua',
#   'table_begin_idx': 9765,
#   'table_len': 751},
#  {'object_type': 'Voucher',
#   'name': 'Money Beanstalk',
#   'set': '',
#   'key': 'moneybean',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasvoucher',
#   'loc_txt': {'name': 'Money Beanstalk',
#    'text': ['Raise the cap on',
#     'interest earned in',
#     'each round to {C:money}$#1#{}']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 5, 'y': 1},
#   'file_name': 'cryptid\\Items\\Vouchers.lua',
#   'table_begin_idx': 10535,
#   'table_len': 606},
#  {'object_type': 'Voucher',
#   'name': 'Universal Fabric',
#   'set': '',
#   'key': 'fabric',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasvoucher',
#   'loc_txt': {'name': 'Universal Fabric',
#    'text': ['{C:dark_edition}+#1#{} Joker slot(s)']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 6, 'y': 0},
#   'file_name': 'cryptid\\Items\\Vouchers.lua',
#   'table_begin_idx': 11157,
#   'table_len': 674},
#  {'object_type': 'Voucher',
#   'name': 'Asteroglyph',
#   'set': '',
#   'key': 'asteroglyph',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasvoucher',
#   'loc_txt': {'name': 'Asteroglyph',
#    'text': ['Set Ante to {C:attention}#1#{}']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 5, 'y': 2},
#   'file_name': 'cryptid\\Items\\Vouchers.lua',
#   'table_begin_idx': 12071,
#   'table_len': 720},
#  {'object_type': 'Voucher',
#   'name': 'Blank Canvas',
#   'set': '',
#   'key': 'blankcanvas',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'atlasvoucher',
#   'loc_txt': {'name': 'Blank Canvas',
#    'text': ['{C:attention}+#1#{} hand size']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 2, 'y': 4},
#   'file_name': 'cryptid\\Items\\Vouchers.lua',
#   'table_begin_idx': 12813,
#   'table_len': 485},
#  {'object_type': 'Tag',
#   'name': 'Triple Tag',
#   'set': '',
#   'key': 'triple',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'tag_cry',
#   'loc_txt': {'name': 'Triple Tag',
#    'text': ['Gives {C:attention}#1#{} copies of the',
#     'next selected {C:attention}Tag',
#     '{s:0.8,C:inactive}Copying Tags excluded']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 0, 'y': 1},
#   'file_name': 'cryptid\\Items\\Vouchers.lua',
#   'table_begin_idx': 13314,
#   'table_len': 1460},
#  {'object_type': 'Tag',
#   'name': 'Quadruple Tag',
#   'set': '',
#   'key': 'quadruple',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'tag_cry',
#   'loc_txt': {'name': 'Quadruple Tag',
#    'text': ['Gives {C:attention}#1#{} copies of the',
#     'next selected {C:attention}Tag',
#     '{s:0.8,C:inactive}Copying Tags excluded']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 1, 'y': 1},
#   'file_name': 'cryptid\\Items\\Vouchers.lua',
#   'table_begin_idx': 14793,
#   'table_len': 1479},
#  {'object_type': 'Tag',
#   'name': 'Quintuple Tag',
#   'set': '',
#   'key': 'quintuple',
#   'path': '',
#   'px': '',
#   'py': '',
#   'atlas': 'tag_cry',
#   'loc_txt': {'name': 'Quintuple Tag',
#    'text': ['Gives {C:attention}#1#{} copies of the',
#     'next selected {C:attention}Tag',
#     '{s:0.8,C:inactive}Copying Tags excluded']},
#   'rarity': '',
#   'cost': '',
#   'pos': {'x': 2, 'y': 1},
#   'file_name': 'cryptid\\Items\\Vouchers.lua',
#   'table_begin_idx': 16291,
#   'table_len': 1483}]

# %%
st = pd.read_csv("Cryptid-汉化-Sheet1.csv")
fed_df = filter(st)

# %%
for index, row in fed_df.iterrows():
    result = next((i for i,d in enumerate(cryptidmods.mod_info) if d.get("key") == row["key"]), None)
    # print(result)
    # print(row["T.loc_txt.text"])
    if row["T.loc_txt.text"] != "":
        cryptidmods.mod_info[result]["T_loc_txt_text"] = row["T.loc_txt.text"]
    
    if row["T.loc_txt.name"] != "":
        cryptidmods.mod_info[result]["T_loc_txt_name"] = row["T.loc_txt.name"]

# %%
cryptidmods.export_excel("cryptid.xlsx" , True)

# %%
st = pd.read_csv("cryptid.csv",encoding='utf-8')

# %%
st.head()
# Out:
#                       file_name object_type            name    set  \
# 0  cryptid\Items\Antimatter.lua        Back       cry-Blank   Back
# 1  cryptid\Items\Antimatter.lua        Back  cry-Antimatter   Back
# 2      cryptid\Items\Blinds.lua       Blind       cry-oldox  Blind
# 3      cryptid\Items\Blinds.lua       Blind    cry-oldhouse  Blind
# 4      cryptid\Items\Blinds.lua       Blind      cry-oldarm  Blind
#
#           key     loc_txt_name T_loc_txt_name  \
# 0       blank       Blank Deck            NaN
# 1  antimatter  Antimatter Deck            NaN
# 2       oldox     Nostalgic Ox            NaN
# 3    oldhouse  Nostalgic House            NaN
# 4      oldarm    Nostalgic Arm            NaN
#
#                                         loc_txt_text T_loc_txt_text  cost  \
# 0                      {C:inactive,E:1}Does nothing?            NaN   NaN
# 1  Applies the {C:legendary,E:1}upsides{}\nof {C:...            NaN   NaN
# 2                      All hands start\nwith 0 Chips            NaN   NaN
# 3                                     No Full Houses            NaN   NaN
# 4                        Must play 4\nor fewer cards   出牌数必须少于等于四张牌   NaN
#
#    rarity
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
def filter(T):
    return T[(T['T_loc_txt_name'].notna()) & (T['T_loc_txt_name'] != '') |
                (T['T_loc_txt_text'].notna()) & (T['T_loc_txt_text'] != '')]

# %%
# ft = filter(st)
ft = st

# %%
descriptions = {}

# %%
for objecttype, group in ft.groupby('object_type'):
    
    typee = objecttype if objecttype != "Consumable" else "Other"
    descriptions[objecttype] = {}
    for row in group.itertuples():
        
        key =  objecttype[0].lower() + "_" + "cry_" + row.key
        if key not in descriptions[objecttype].keys():
            descriptions[objecttype][key] = {}
        
        descriptions[objecttype][key]["name"] = row.loc_txt_name if pd.isna(row.T_loc_txt_name)  else row.T_loc_txt_name
        texts = row.loc_txt_text if pd.isna(row.T_loc_txt_text)  else row.T_loc_txt_text
        descriptions[objecttype][key]["text"] = str(texts).split("\n")

# %%
def dict_to_lua_table(d, indent=0):
    """将 Python 字典转换为 Lua table 格式的字符串，并添加缩进和换行。"""
    indent_str = "\t" * (indent+1)
    next_indent_str = "\t" * (indent + 2)
    
    if isinstance(d, dict):
        items = []
        for key, value in d.items():
            # 递归处理键值对，key 必须是字符串，并且放在 Lua 格式的括号中
            items.append(f'{next_indent_str}{key} = {dict_to_lua_table(value, indent + 1)}')
        return "{\n" + ",\n".join(items) + "\n" + indent_str + "}"
    
    elif isinstance(d, list):
        items = [f'{next_indent_str}"{item}"' for item in d]
        return "{\n" + ",\n".join(items) + "\n" + indent_str + "}"
    
    elif isinstance(d, str):
        # 处理字符串类型，保留双引号
        return f'"{d}"'
    
    else:
        # 处理其他类型，转换为字符串格式
        return str(d)

# %%
# print(dict_to_lua_table(descriptions))
table =dict_to_lua_table(descriptions)

# %%
res = "return {\n" + "\tdescriptions="+table + "\n}"

# %%
print(res)
# Out:
# return {
# 	descriptions={
# 		Back = {
# 			b_cry_blank = {
# 				name = "Blank Deck",
# 				text = {
# 					"{C:inactive,E:1}Does nothing?"
# 				}
# 			},
# 			b_cry_antimatter = {
# 				name = "Antimatter Deck",
# 				text = {
# 					"Applies the {C:legendary,E:1}upsides{}",
# 					"of {C:attention}every{} deck"
# 				}
# 			},
# 			b_cry_encoded = {
# 				name = "Encoded Deck",
# 				text = {
# 					"Start with a {C:cry_code,T:j_cry_CodeJoker}Code Joker{}",
# 					"and a {C:cry_code,T:j_cry_copypaste}Copy/Paste{}",
# 					"Only {C:cry_code}Code Cards{} appear in shop"
# 				}
# 			},
# 			b_cry_source_deck = {
# 				name = "Source Deck",
# 				text = {
# 					"All cards have a {C:cry_code}Green Seal{}",
# 					"Cards cannot change seals"
# 				}
# 			},
# 			b_cry_very_fair = {
# 				name = "Very Fair Deck",
# 				text = {
# 					"{C:blue}-2{} hands, {C:red}-2{} discards",
# 					"every round",
# 					"{C:attention}Vouchers{} no longer",
# 					"appear in the shop"
# 				}
# 			},
# 			b_cry_equilibrium = {
# 				name = "Deck of Equilibrium",
# 				text = {
# 					"All cards have the",
# 					"{C:attention}same chance{} of",
# 					"appearing in shops,",
# 					"start run with",
# 					"{C:attention,T:v_overstock_plus}Overstock Plus"
# 				}
# 			},
# 			b_cry_misprint = {
# 				name = "Misprint Deck",
# 				text = {
# 					"Values of cards",
# 					"and poker hands",
# 					"are {C:attention}randomized"
# 				}
# 			},
# 			b_cry_infinite = {
# 				name = "Infinite Deck",
# 				text = {
# 					"You can select {C:attention}any",
# 					"number of cards",
# 					"{C:attention}+1{} hand size"
# 				}
# 			},
# 			b_cry_conveyor = {
# 				name = "Conveyor Deck",
# 				text = {
# 					"Jokers may {C:attention}not{} be moved",
# 					"At start of round,",
# 					"{C:attention}duplicate{} rightmost Joker",
# 					"and {C:attention}destroy{} leftmost Joker"
# 				}
# 			},
# 			b_cry_CCD = {
# 				name = "CCD Deck",
# 				text = {
# 					"Every card is also",
# 					"a {C:attention}random{} consumable"
# 				}
# 			},
# 			b_cry_wormhole = {
# 				name = "Wormhole Deck",
# 				text = {
# 					"Start with an {C:cry_exotic}Exotic{C:attention} Joker",
# 					"Jokers are {C:attention}20X{} more",
# 					"likely to be {C:dark_edition}Negative",
# 					"{C:attention}-2{} Joker slots"
# 				}
# 			},
# 			b_cry_redeemed = {
# 				name = "Redeemed Deck",
# 				text = {
# 					"When a {C:attention}Voucher{} is purchased,",
# 					"gain its {C:attention}extra tiers"
# 				}
# 			},
# 			b_cry_critical = {
# 				name = "Critical Deck",
# 				text = {
# 					"After each hand played,",
# 					"{C:green}#1# in 4{} chance for {X:dark_edition,C:white} ^2 {} Mult",
# 					"{C:green}#1# in 8{} chance for {X:dark_edition,C:white} ^0.5 {} Mult"
# 				}
# 			},
# 			b_cry_glowing = {
# 				name = "Glowing Deck",
# 				text = {
# 					"Multiply the values of",
# 					"all Jokers by {X:dark_edition,C:white} X1.25 {}",
# 					"when Boss Blind is defeated",
# 					"{X:cry_jolly,C:white,s:0.8} Jolly#1#Open#1#Winner#1#-#1#wawa#1#person"
# 				}
# 			}
# 		},
# 		Blind = {
# 			b_cry_oldox = {
# 				name = "Nostalgic Ox",
# 				text = {
# 					"All hands start",
# 					"with 0 Chips"
# 				}
# 			},
# 			b_cry_oldhouse = {
# 				name = "Nostalgic House",
# 				text = {
# 					"No Full Houses"
# 				}
# 			},
# 			b_cry_oldarm = {
# 				name = "Nostalgic Arm",
# 				text = {
# 					"出牌数必须少于等于四张牌"
# 				}
# 			},
# 			b_cry_oldfish = {
# 				name = "Nostalgic Fish",
# 				text = {
# 					"All hands start",
# 					"with 1 Mult"
# 				}
# 			},
# 			b_cry_oldmanacle = {
# 				name = "Nostalgic Manacle",
# 				text = {
# 					"弃牌减少倍率"
# 				}
# 			},
# 			b_cry_oldserpent = {
# 				name = "Nostalgic Serpent",
# 				text = {
# 					"Divide Mult by level",
# 					"of played poker hand"
# 				}
# 			},
# 			b_cry_oldpillar = {
# 				name = "Nostalgic Pillar",
# 				text = {
# 					"No Straights"
# 				}
# 			},
# 			b_cry_oldflint = {
# 				name = "Nostalgic Flint",
# 				text = {
# 					"No Flushes"
# 				}
# 			},
# 			b_cry_oldmark = {
# 				name = "Nostalgic Mark",
# 				text = {
# 					"No hands that",
# 					"contain a Pair"
# 				}
# 			},
# 			b_cry_tax = {
# 				name = "The Tax",
# 				text = {
# 					"Score per hand capped at",
# 					"0.4X blind requirements"
# 				}
# 			},
# 			b_cry_box = {
# 				name = "The Box",
# 				text = {
# 					"All Common Jokers",
# 					"are debuffed"
# 				}
# 			},
# 			b_cry_clock = {
# 				name = "The Clock",
# 				text = {
# 					"+0.1X blind requirements every",
# 					"3 seconds spent this ante"
# 				}
# 			},
# 			b_cry_trick = {
# 				name = "The Trick",
# 				text = {
# 					"After each hand, flip all",
# 					"face-up cards held in hand"
# 				}
# 			},
# 			b_cry_joke = {
# 				name = "The Joke",
# 				text = {
# 					"If score is >2X requirements,",
# 					"set ante to multiple of #1#"
# 				}
# 			},
# 			b_cry_hammer = {
# 				name = "The Hammer",
# 				text = {
# 					"所有奇数牌都被削弱"
# 				}
# 			},
# 			b_cry_magic = {
# 				name = "The Magic",
# 				text = {
# 					"All cards with even",
# 					"rank are debuffed"
# 				}
# 			},
# 			b_cry_windmill = {
# 				name = "The Windmill",
# 				text = {
# 					"All Uncommon Jokers",
# 					"are debuffed"
# 				}
# 			},
# 			b_cry_striker = {
# 				name = "The Striker",
# 				text = {
# 					"All Rare Jokers",
# 					"are debuffed"
# 				}
# 			},
# 			b_cry_shackle = {
# 				name = "The Shackle",
# 				text = {
# 					"All Negative Jokers",
# 					"are debuffed"
# 				}
# 			},
# 			b_cry_pin = {
# 				name = "The Pin",
# 				text = {
# 					"Jokers with Epic or higher",
# 					"rarity are debuffed"
# 				}
# 			},
# 			b_cry_pinkbow = {
# 				name = "Pink Bow",
# 				text = {
# 					"Randomize rank of cards",
# 					"held in hand on play"
# 				}
# 			},
# 			b_cry_lavender_loop = {
# 				name = "Lavender Loop",
# 				text = {
# 					"这回合每过1.5秒",
# 					"所需要的分数X1.25"
# 				}
# 			},
# 			b_cry_tornado = {
# 				name = "Turquoise Tornado",
# 				text = {
# 					"#1# in #2# chance for",
# 					"played hand to not score"
# 				}
# 			},
# 			b_cry_vermillion_virus = {
# 				name = "Vermillion Virus",
# 				text = {
# 					"每次出牌随机一张小丑被替换"
# 				}
# 			},
# 			b_cry_sapphire_stamp = {
# 				name = "Sapphire Stamp",
# 				text = {
# 					"Select an extra card, deselect",
# 					"random card before scoring"
# 				}
# 			},
# 			b_cry_obsidian_orb = {
# 				name = "Obsidian Orb",
# 				text = {
# 					"拥有所有被击败的BOOS的能力"
# 				}
# 			}
# 		},
# 		Booster = {
# 			b_cry_code_normal_1 = {
# 				name = "Program Pack",
# 				text = {
# 					"Choose {C:attention}#1#{} of up to",
# 					"{C:attention}#2#{C:cry_code} Code{} cards"
# 				}
# 			},
# 			b_cry_code_normal_2 = {
# 				name = "Program Pack",
# 				text = {
# 					"Choose {C:attention}#1#{} of up to",
# 					"{C:attention}#2#{C:cry_code} Code{} cards"
# 				}
# 			},
# 			b_cry_code_jumbo_1 = {
# 				name = "Jumbo Program Pack",
# 				text = {
# 					"Choose {C:attention}#1#{} of up to",
# 					"{C:attention}#2#{C:cry_code} Code{} cards"
# 				}
# 			},
# 			b_cry_code_mega_1 = {
# 				name = "Mega Program Pack",
# 				text = {
# 					"Choose {C:attention}#1#{} of up to",
# 					"{C:attention}#2#{C:cry_code} Code{} cards"
# 				}
# 			},
# 			b_cry_meme_1 = {
# 				name = "Meme Pack",
# 				text = {
# 					"Choose {C:attention}#1#{} of",
# 					"up to {C:attention}#2# Meme Jokers{}"
# 				}
# 			},
# 			b_cry_meme_two = {
# 				name = "Meme Pack",
# 				text = {
# 					"Choose {C:attention}#1#{} of",
# 					"up to {C:attention}#2# Meme Jokers{}"
# 				}
# 			},
# 			b_cry_meme_three = {
# 				name = "Meme Pack",
# 				text = {
# 					"Choose {C:attention}#1#{} of",
# 					"up to {C:attention}#2# Meme Jokers{}"
# 				}
# 			},
# 			b_cry_empowered = {
# 				name = "Spectral Pack [Empowered Tag]",
# 				text = {
# 					"Choose {C:attention}#1#{} of up to",
# 					"{C:attention}#2#{C:spectral} Spectral{} cards",
# 					"{s:0.8,C:inactive}(Generated by Empowered Tag)"
# 				}
# 			}
# 		},
# 		Consumable = {
# 			c_cry_crash = {
# 				name = "://CRASH",
# 				text = {
# 					"{C:cry_code,E:1}Don't."
# 				}
# 			},
# 			c_cry_payload = {
# 				name = "://PAYLOAD",
# 				text = {
# 					"Next defeated Blind",
# 					"gives {C:cry_code}X#1#{} interest"
# 				}
# 			},
# 			c_cry_reboot = {
# 				name = "://REBOOT",
# 				text = {
# 					"Replenish {C:blue}Hands{} and {C:red}Discards{},",
# 					"return {C:cry_code}all{} cards to deck",
# 					"and draw a {C:cry_code}new{} hand"
# 				}
# 			},
# 			c_cry_revert = {
# 				name = "://REVERT",
# 				text = {
# 					"Set {C:cry_code}game state{} to",
# 					"start of {C:cry_code}this Ante{}"
# 				}
# 			},
# 			c_cry_semicolon = {
# 				name = ";//",
# 				text = {
# 					"Ends current non-Boss {C:cry_code}Blind{}",
# 					"{C:cry_code}without{} cashing out"
# 				}
# 			},
# 			c_cry_malware = {
# 				name = "://MALWARE",
# 				text = {
# 					"Add {C:dark_edition}Glitched{} to all",
# 					"cards {C:cry_code}held in hand"
# 				}
# 			},
# 			c_cry_seed = {
# 				name = "://SEED",
# 				text = {
# 					"Select a Joker",
# 					"or playing card",
# 					"to become {C:cry_code}Rigged"
# 				}
# 			},
# 			c_cry_hook = {
# 				name = "HOOK://",
# 				text = {
# 					"Select two Jokers",
# 					"to become {C:cry_code}Hooked"
# 				}
# 			},
# 			c_cry_variable = {
# 				name = "://VARIABLE",
# 				text = {
# 					"Convert {C:cry_code}#1#{} selected cards",
# 					"to a {C:cry_code}chosen{} rank"
# 				}
# 			},
# 			c_cry_class = {
# 				name = "://CLASS",
# 				text = {
# 					"Convert {C:cry_code}#1#{} selected card",
# 					"to a {C:cry_code}chosen{} enhancement"
# 				}
# 			},
# 			c_cry_commit = {
# 				name = "://COMMIT",
# 				text = {
# 					"Destroy a {C:cry_code}selected{} Joker,",
# 					"create a {C:cry_code}new{} Joker",
# 					"of the {C:cry_code}same rarity"
# 				}
# 			},
# 			c_cry_merge = {
# 				name = "://MERGE",
# 				text = {
# 					"Merge a selected {C:cry_code}consumable",
# 					"with a selected {C:cry_code}playing card"
# 				}
# 			},
# 			c_cry_multiply = {
# 				name = "://MULTIPLY",
# 				text = {
# 					"{C:cry_code}Double{} all values of",
# 					"a selected {C:cry_code}Joker{} until",
# 					"end of round"
# 				}
# 			},
# 			c_cry_divide = {
# 				name = "://DIVIDE",
# 				text = {
# 					"{C:cry_code}Halve{} all listed prices",
# 					"in current shop"
# 				}
# 			},
# 			c_cry_delete = {
# 				name = "://DELETE",
# 				text = {
# 					"{C:cry_code}Permanently{} remove a",
# 					"{C:cry_code}selected{} shop item",
# 					"{C:inactive,s:0.8}Item cannot appear again this run"
# 				}
# 			},
# 			c_cry_spaghetti = {
# 				name = "://SPAGHETTI",
# 				text = {
# 					"Create a {C:cry_code}Glitched",
# 					"Food Joker"
# 				}
# 			},
# 			c_cry_machinecode = {
# 				name = "://MACHINECODE",
# 				text = {
# 					"nan"
# 				}
# 			},
# 			c_cry_run = {
# 				name = "://RUN",
# 				text = {
# 					"Visit a {C:cry_code}shop",
# 					"during a {C:cry_code}Blind"
# 				}
# 			},
# 			c_cry_exploit = {
# 				name = "://EXPLOIT",
# 				text = {
# 					"The {C:cry_code}next{} hand played",
# 					"is calculated as a",
# 					"{C:cry_code}chosen{} poker hand",
# 					"{C:inactive,s:0.8}Secret hands must be",
# 					"{C:inactive,s:0.8}discovered to be valid"
# 				}
# 			},
# 			c_cry_oboe = {
# 				name = "://OFFBYONE",
# 				text = {
# 					"Next {C:cry_code}Booster Pack{} has",
# 					"{C:cry_code}#1#{} extra card and",
# 					"{C:cry_code}#1#{} extra choice",
# 					"{C:inactive}(Currently {C:cry_code}+#2#{C:inactive})"
# 				}
# 			},
# 			c_cry_rework = {
# 				name = "://REWORK",
# 				text = {
# 					"Destroy a {C:cry_code}selected{} Joker,",
# 					"create a {C:cry_code}Rework Tag{} with",
# 					"an {C:cry_code}upgraded{} edition",
# 					"{C:inactive,s:0.8}Upgrades using order in the Collection"
# 				}
# 			},
# 			c_cry_automaton = {
# 				name = "The Automaton",
# 				text = {
# 					"Creates up to {C:attention}#1#",
# 					"random {C:cry_code}Code{} card",
# 					"{C:inactive}(Must have room)"
# 				}
# 			},
# 			c_cry_source = {
# 				name = "Source",
# 				text = {
# 					"Add a {C:cry_code}Green Seal{}",
# 					"to {C:attention}#1#{} selected",
# 					"card in your hand"
# 				}
# 			},
# 			c_cry_pointer = {
# 				name = "POINTER://",
# 				text = {
# 					"Create a card",
# 					"of {C:cry_code}your choice",
# 					"{C:inactive,s:0.8}(Exotic Jokers #1#excluded)"
# 				}
# 			},
# 			c_cry_gateway = {
# 				name = "Gateway",
# 				text = {
# 					"摧毁其他所有小丑",
# 					"生成一个{C:cry_exotic,E:1}Exotic{C:attention} 小丑{}"
# 				}
# 			},
# 			c_cry_eclipse = {
# 				name = "The Eclipse",
# 				text = {
# 					"Enhances {C:attention}#1#{} selected card",
# 					"into an {C:attention}Echo Card"
# 				}
# 			},
# 			c_cry_theblessing = {
# 				name = "The Blessing",
# 				text = {
# 					"Creates {C:attention}1{}",
# 					"random {C:attention}consumable{}",
# 					"{C:inactive}(Must have room){}"
# 				}
# 			},
# 			c_cry_typhoon = {
# 				name = "Typhoon",
# 				text = {
# 					"Add an {C:cry_azure}Azure Seal{}",
# 					"to {C:attention}#1#{} selected",
# 					"card in your hand"
# 				}
# 			},
# 			c_cry_Timantti = {
# 				name = "Timantti",
# 				text = {
# 					"({V:1}lvl.#4#{})({V:2}lvl.#5#{})({V:3}lvl.#6#{})",
# 					"Level up",
# 					"{C:attention}#1#{},",
# 					"{C:attention}#2#{},",
# 					"and {C:attention}#3#{}"
# 				}
# 			},
# 			c_cry_Klubi = {
# 				name = "Klubi",
# 				text = {
# 					"({V:1}lvl.#4#{})({V:2}lvl.#5#{})({V:3}lvl.#6#{})",
# 					"Level up",
# 					"{C:attention}#1#{},",
# 					"{C:attention}#2#{},",
# 					"and {C:attention}#3#{}"
# 				}
# 			},
# 			c_cry_Sydan = {
# 				name = "Sydan",
# 				text = {
# 					"({V:1}lvl.#4#{})({V:2}lvl.#5#{})({V:3}lvl.#6#{})",
# 					"Level up",
# 					"{C:attention}#1#{},",
# 					"{C:attention}#2#{},",
# 					"and {C:attention}#3#{}"
# 				}
# 			},
# 			c_cry_Lapio = {
# 				name = "Lapio",
# 				text = {
# 					"({V:1}lvl.#4#{})({V:2}lvl.#5#{})({V:3}lvl.#6#{})",
# 					"Level up",
# 					"{C:attention}#1#{},",
# 					"{C:attention}#2#{},",
# 					"and {C:attention}#3#{}"
# 				}
# 			},
# 			c_cry_planetlua = {
# 				name = "Planet.lua",
# 				text = {
# 					"{C:green}#1# in #2#{} chance to",
# 					"upgrade every",
# 					"{C:legendary,E:1}poker hand{}",
# 					"by {C:attention}1{} level"
# 				}
# 			},
# 			c_cry_nstar = {
# 				name = "Neutron Star",
# 				text = {
# 					"升级一个随机的手牌类型",
# 					"每使用一次此星球牌升1级",
# 					"{C:inactive}(当前使用：{C:attention} #1#{C:inactive}){}"
# 				}
# 			},
# 			c_cry_white_hole = {
# 				name = "White Hole",
# 				text = {
# 					"{C:attention}Remove{} all hand levels,",
# 					"upgrade {C:legendary,E:1}most played{} poker hand",
# 					"by {C:attention}3{} for each removed level"
# 				}
# 			},
# 			c_cry_vacuum = {
# 				name = "Vacuum",
# 				text = {
# 					"Removes {C:red}all {C:green}modifications{}",
# 					"from {C:red}all{} cards held in hand,",
# 					"Earn {C:money}$#1#{} per {C:green}modification{} removed",
# 					"{C:inactive,s:0.7}(ex. Enhancements, Seals, Editions)"
# 				}
# 			},
# 			c_cry_hammerspace = {
# 				name = "Hammerspace",
# 				text = {
# 					"Apply random {C:attention}consumables{}",
# 					"as if they were {C:dark_edition}Enhancements{}",
# 					"to cards held in hand"
# 				}
# 			},
# 			c_cry_lock = {
# 				name = "Lock",
# 				text = {
# 					"Remove {C:red}all{} stickers",
# 					"from {C:red}all{} Jokers,",
# 					"then apply {C:purple,E:1}Eternal{}",
# 					"to a random {C:attention}Joker{}"
# 				}
# 			},
# 			c_cry_trade = {
# 				name = "Trade",
# 				text = {
# 					"{C:attention}Lose{} a random Voucher,",
# 					"gain {C:attention}2{} random Vouchers"
# 				}
# 			},
# 			c_cry_analog = {
# 				name = "Analog",
# 				text = {
# 					"Create {C:attention}#1#{} copies of a",
# 					"random {C:attention}Joker{}, destroy",
# 					"all other Jokers, {C:attention}+#2#{} Ante"
# 				}
# 			},
# 			c_cry_summoning = {
# 				name = "Summoning",
# 				text = {
# 					"Create a random",
# 					"{C:cry_epic}Epic{} {C:joker}Joker{}, destroy",
# 					"one random {C:joker}Joker{}"
# 				}
# 			},
# 			c_cry_replica = {
# 				name = "Replica",
# 				text = {
# 					"Convert all cards",
# 					"held in hand",
# 					"to a {C:attention}random{}",
# 					"card held in hand"
# 				}
# 			}
# 		},
# 		Enhancement = {
# 			e_cry_echo = {
# 				name = "Echo Card",
# 				text = {
# 					"{C:green}#2# in #3#{} chance to",
# 					"{C:attention}retrigger{} #1# additional",
# 					"times when scored"
# 				}
# 			}
# 		},
# 		Joker = {
# 			j_cry_CodeJoker = {
# 				name = "代码小丑",
# 				text = {
# 					"当选择{C:attention}盲注{}时",
# 					"创建一个{C:dark_edition}负片{}{C:cry_code}代码牌{}"
# 				}
# 			},
# 			j_cry_copypaste = {
# 				name = "复制/粘贴",
# 				text = {
# 					"当 {C:cry_code}代码牌{} 被使用,",
# 					"{C:green}#1# / #2#{}概率复制一张到你的消耗槽"
# 				}
# 			},
# 			j_cry_cut = {
# 				name = "剪切",
# 				text = {
# 					"这张小丑摧毁一个随机的 {C:cry_code}代码牌{}",
# 					"并且增加 {X:mult,C:white} X#1# {} 倍率在 {C:attention}商店购物{}之后",
# 					"{C:inactive}(当前已提供{X:mult,C:white} X#2# {C:inactive} 倍率)"
# 				}
# 			},
# 			j_cry_blender = {
# 				name = "Blender",
# 				text = {
# 					"每当一张{C:cry_code}代码牌{} 被使用",
# 					"获得一张 {C:attention}随机{}消耗牌"
# 				}
# 			},
# 			j_cry_python = {
# 				name = "Python",
# 				text = {
# 					"",
# 					"每使用一张{C:cry_code}代码牌{}，这张牌增加{X:mult,C:white} X#1# {}倍率",
# 					"{C:inactive}(当前已提供{X:mult,C:white} X#2# {C:inactive} 倍率)"
# 				}
# 			},
# 			j_cry_supercell = {
# 				name = "Supercell",
# 				text = {
# 					"{C:chips}+#1#{} Chips, {C:mult}+#1#{} Mult,",
# 					"{X:chips,C:white}X#2#{} Chips, {X:mult,C:white}X#2#{} Mult",
# 					"Earn {C:money}$#3#{} at",
# 					"end of round"
# 				}
# 			},
# 			j_cry_googol_play = {
# 				name = "Googol Play Card",
# 				text = {
# 					"{C:green}#1# in #2#{} chance for",
# 					"{X:red,C:white} X#3# {} Mult"
# 				}
# 			},
# 			j_cry_sync_catalyst = {
# 				name = "Sync Catalyst",
# 				text = {
# 					"Balances {C:chips}Chips{} and {C:mult}Mult{}",
# 					"{C:inactive,s:0.8}Hey! I"ve seen this one before!"
# 				}
# 			},
# 			j_cry_negative = {
# 				name = "Negative Joker",
# 				text = {
# 					"{C:dark_edition}+#1#{C:attention} Joker{} slots"
# 				}
# 			},
# 			j_cry_canvas = {
# 				name = "Canvas",
# 				text = {
# 					"{C:attention}Retrigger{} all {C:attention}Jokers{} to the left",
# 					"once for {C:attention}every{} non-{C:blue}Common{C:attention} Joker{}",
# 					"to the right of this Joker"
# 				}
# 			},
# 			j_cry_error = {
# 				name = "{C:red}ERR{}{C:dark_edition}O{}{C:red}R{}",
# 				text = {
# 					"nan"
# 				}
# 			},
# 			j_cry_m = {
# 				name = "m",
# 				text = {
# 					"This Joker gains {X:mult,C:white} X#1# {} Mult",
# 					"when {C:attention}Jolly Joker{} is sold",
# 					"{C:inactive}(Currently {X:mult,C:white} X#2# {C:inactive} Mult)"
# 				}
# 			},
# 			j_cry_M = {
# 				name = "M",
# 				text = {
# 					"Create a {C:dark_edition}Negative{}",
# 					"{C:attention}Jolly Joker{} when",
# 					"{C:attention}Blind{} is selected"
# 				}
# 			},
# 			j_cry_boredom = {
# 				name = "Boredom",
# 				text = {
# 					"{C:green}#1# in #2#{} chance to",
# 					"{C:attention}retrigger{} each {C:attention}Joker{}",
# 					"or {C:attention}played card{}",
# 					"{C:inactive,s:0.8}Does not affect other Boredom{}"
# 				}
# 			},
# 			j_cry_number_blocks = {
# 				name = "Number Blocks",
# 				text = {
# 					"Earn {C:money}$#1#{} at end of round",
# 					"Increase payout by {C:money}$#2#{}",
# 					"for each {C:attention}#3#{} held in hand,",
# 					"rank changes every round"
# 				}
# 			},
# 			j_cry_Double Scale = {
# 				name = "Double Scale",
# 				text = {
# 					"Scaling {C:attention}Jokers{}",
# 					"scale {C:attention}quadratically",
# 					"{C:inactive,s:0.8}(ex. +1, +3, +6, +10)",
# 					"{C:inactive,s:0.8}(grows by +1, +2, +3)"
# 				}
# 			},
# 			j_cry_oldcandy = {
# 				name = "Nostalgic Candy",
# 				text = {
# 					"Sell this card to",
# 					"permanently gain",
# 					"{C:attention}+#1#{} hand size"
# 				}
# 			},
# 			j_cry_circus = {
# 				name = "Circus",
# 				text = {
# 					"{C:red}Rare{} Jokers each give {X:mult,C:white} X#1# {} Mult",
# 					"{C:cry_epic}Epic{} Jokers each give {X:mult,C:white} X#2# {} Mult",
# 					"{C:legendary}Legendary{} Jokers each give {X:mult,C:white} X#3# {} Mult",
# 					"{C:cry_exotic}Exotic{} Jokers each give {X:mult,C:white} X#4# {} Mult"
# 				}
# 			},
# 			j_cry_caramel = {
# 				name = "Caramel",
# 				text = {
# 					"Each played card gives",
# 					"{X:mult,C:white}X#1#{} Mult when scored",
# 					"for the next {C:attention}#2#{} rounds"
# 				}
# 			},
# 			j_cry_curse = {
# 				name = "Sob",
# 				text = {
# 					"{C:edition,E:1}you cannot{} {C:cry_ascendant,E:1}run...{}",
# 					"{C:edition,E:1}you cannot{} {C:cry_ascendant,E:1}hide...{}",
# 					"{C:dark_edition,E:1}you cannot escape...{}",
# 					"{C:inactive}(Must have room){}"
# 				}
# 			},
# 			j_cry_bonusjoker = {
# 				name = "Bonus Joker",
# 				text = {
# 					"{C:green}#1# in #2#{} chance for each",
# 					"played {C:attention}Bonus{} card to increase",
# 					"{C:attention}Joker{} or {C:attention}Consumable slots",
# 					"by {C:dark_edition}1{} when scored",
# 					"{C:red}Works twice per round",
# 					"{C:inactive,s:0.8}(Equal chance for each){}"
# 				}
# 			},
# 			j_cry_multjoker = {
# 				name = "Mult Joker",
# 				text = {
# 					"{C:green}#1# in #2#{} chance for each",
# 					"played {C:attention}Mult{} card to create",
# 					"a {C:spectral}Cryptid{} card when scored",
# 					"{C:inactive}(Must have room)"
# 				}
# 			},
# 			j_cry_goldjoker = {
# 				name = "Gold Joker",
# 				text = {
# 					"Earn {C:money}#1#%{} of total",
# 					"money at end of round",
# 					"Payout increases by {C:money}#2#%{}",
# 					"when each played {C:attention}Gold{}",
# 					"card is scored"
# 				}
# 			},
# 			j_cry_altgoogol = {
# 				name = "Nostalgic Googol Play Card",
# 				text = {
# 					"Sell this card to create",
# 					"{C:attention}2{} copies of the leftmost {C:attention}Joker{}",
# 					"{C:inactive,s:0.8}Does not copy Nostalgic Googol Play Cards{}"
# 				}
# 			},
# 			j_cry_iterum = {
# 				name = "Iterum",
# 				text = {
# 					"已经出过的牌重新触发{C:attention}#2#{}次",
# 					"并且每张牌提供{X:mult,C:white} X#1# {} 倍率"
# 				}
# 			},
# 			j_cry_universum = {
# 				name = "Universum",
# 				text = {
# 					"{C:attention}Poker hands{} gain",
# 					"{X:red,C:white} X#1# {} Mult and {X:blue,C:white} X#1# {} Chips",
# 					"when leveled up"
# 				}
# 			},
# 			j_cry_exponentia = {
# 				name = "Exponentia",
# 				text = {
# 					"This Joker gains {X:dark_edition,C:white} ^#1# {} Mult",
# 					"when {X:red,C:white} XMult {} is triggered",
# 					"{C:inactive}(Currently {X:dark_edition,C:white} ^#2# {C:inactive} Mult)"
# 				}
# 			},
# 			j_cry_speculo = {
# 				name = "Speculo",
# 				text = {
# 					"Creates a {C:dark_edition}Negative{} copy",
# 					"of a random {C:attention}Joker{}",
# 					"at the end of the {C:attention}shop",
# 					"{C:inactive,s:0.8}Does not copy other Speculo{}"
# 				}
# 			},
# 			j_cry_redeo = {
# 				name = "Redeo",
# 				text = {
# 					"{C:attention}-#1#{} Ante when",
# 					"{C:money}$#2#{} {C:inactive}($#3#){} spent",
# 					"{s:0.8}Requirements increase",
# 					"{C:attention,s:0.8}exponentially{s:0.8} per use",
# 					"{C:money,s:0.8}Next increase: {s:1,c:money}$#4#"
# 				}
# 			},
# 			j_cry_tenebris = {
# 				name = "Tenebris",
# 				text = {
# 					"{C:dark_edition}+#1#{C:attention} Joker{} slots",
# 					"Earn {C:money}$#2#{} at end of round"
# 				}
# 			},
# 			j_cry_effarcire = {
# 				name = "Effarcire",
# 				text = {
# 					"Draw {C:green}full deck{} to hand",
# 					"when {C:attention}Blind{} is selected",
# 					"{C:inactive,s:0.8}If you can't handle me at my 1x,",
# 					"{C:inactive,s:0.8}you don't deserve me at my 2x"
# 				}
# 			},
# 			j_cry_crustulum = {
# 				name = "Crustulum",
# 				text = {
# 					"This Joker gains {C:chips}+#2#{} Chips",
# 					"per {C:attention}reroll{} in the shop",
# 					"{C:green}All rerolls are free{}",
# 					"{C:inactive}(Currently {C:chips}+#1#{C:inactive} chips)"
# 				}
# 			},
# 			j_cry_primus = {
# 				name = "Primus",
# 				text = {
# 					"This Joker gains {X:dark_edition,C:white} ^#1# {} Mult",
# 					"if all cards in played hand are",
# 					"{C:attention}Aces{}, {C:attention}2s{}, {C:attention}3s{}, {C:attention}5s{}, or {C:attention}7s{}",
# 					"{C:inactive}(Currently {X:dark_edition,C:white} ^#2# {C:inactive} Mult)"
# 				}
# 			},
# 			j_cry_Scalae = {
# 				name = "Scalae",
# 				text = {
# 					"Scaling {C:attention}Jokers{} scale",
# 					"as a degree-{C:attention}#1#{} polynomial",
# 					"raise degree by {C:attention}#2#{}",
# 					"at end of round",
# 					"{C:inactive,s:0.8}({C:attention,s:0.8}Scalae{C:inactive,s:0.8} excluded)"
# 				}
# 			},
# 			j_cry_stella_mortis = {
# 				name = "Stella Mortis",
# 				text = {
# 					"This Joker destroys a",
# 					"random {C:planet}Planet{} card",
# 					"and gains {X:dark_edition,C:white} ^#1# {} Mult",
# 					"at the end of the {C:attention}shop{}",
# 					"{C:inactive}(Currently {X:dark_edition,C:white} ^#2# {C:inactive} Mult)"
# 				}
# 			},
# 			j_cry_circulus_pistoris = {
# 				name = "Circulus Pistoris",
# 				text = {
# 					"{X:dark_edition,C:white}^#1#{} Chips, {X:dark_edition,C:white}^#1#{} Mult",
# 					"if {C:attention}exactly{} #2#",
# 					"hands remaining"
# 				}
# 			},
# 			j_cry_equilib = {
# 				name = "Ace Aequilibrium",
# 				text = {
# 					"Jokers appear using the",
# 					"order from the {C:attention}Collection{}",
# 					"Create {C:attention}#1#{} {C:dark_edition}Negative{} Joker(s)",
# 					"when hand is played",
# 					"{C:cry_exotic,s:0.8}Exotic {C:inactive,s:0.8}or better Jokers cannot appear",
# 					"{s:0.8}Last Joker Generated: {C:attention,s:0.8}#2#"
# 				}
# 			},
# 			j_cry_facile = {
# 				name = "Facile",
# 				text = {
# 					"{X:dark_edition,C:white}^#1#{} Mult if",
# 					"{C:attention}#2#{} or fewer",
# 					"cards are scored"
# 				}
# 			},
# 			j_cry_gemino = {
# 				name = "Gemini",
# 				text = {
# 					"{C:attention}Double{} all values",
# 					"of leftmost {C:attention}Joker",
# 					"at end of round"
# 				}
# 			},
# 			j_cry_energia = {
# 				name = "Energia",
# 				text = {
# 					"When a {C:attention}Tag{} is acquired,",
# 					"create {C:attention}#1#{} copies of it",
# 					"and {C:attention}increase{} the number of",
# 					"copies by {C:attention}#2#"
# 				}
# 			},
# 			j_cry_verisimile = {
# 				name = "Non Verisimile",
# 				text = {
# 					"When any probability",
# 					"is {C:green}successfully{} triggered,",
# 					"this Joker gains {X:red,C:white}XMult{}",
# 					"equal to its listed {C:attention}odds",
# 					"{C:inactive}(Currently {X:mult,C:white} X#1# {C:inactive} Mult)"
# 				}
# 			},
# 			j_cry_jollysus = {
# 				name = "开心小丑。。吗？",
# 				text = {
# 					"当一个小丑被 {C:attention}出售{}时",
# 					"创建一个 {C:dark_edition}开心{} 小丑",
# 					"{C:red}每回合只生效一次{}",
# 					"{C:inactive}#1#{}"
# 				}
# 			},
# 			j_cry_kidnap = {
# 				name = "Kidnapping",
# 				text = {
# 					"Earn {C:money}$#1#{} and Create a {C:attention}Jolly{}",
# 					"{C:attention}Joker{} when {C:attention}Zany Joker{},",
# 					"{C:attention}Mad Joker{}, {C:attention}Crazy Joker{},",
# 					"or {C:attention}Droll Joker{} is {C:attention}sold{}"
# 				}
# 			},
# 			j_cry_bubblem = {
# 				name = "Bubble M",
# 				text = {
# 					"Create a {C:dark_edition}Foil {C:attention}Jolly Joker{}",
# 					"if played hand contains",
# 					"a {C:attention}#1#{}",
# 					"{C:red,E:2}self destructs{}"
# 				}
# 			},
# 			j_cry_foodm = {
# 				name = "Fast Food M",
# 				text = {
# 					"{C:mult}+#1#{} Mult",
# 					"{C:red,E:2}self destructs{} in {C:attention}#2#{} round#3#",
# 					"Increases by {C:attention}#4#{} round when",
# 					"{C:attention}Jolly Joker{} is {C:attention}sold{}",
# 					"{C:inactive,s:0.8}2 McDoubles, 2 McChickens{}",
# 					"{C:inactive,s:0.8}Large Fries, 20 Piece & Large Cake{}"
# 				}
# 			},
# 			j_cry_mstack = {
# 				name = "M Stack",
# 				text = {
# 					"Retrigger all cards played",
# 					"once for every",
# 					"{C:attention}#2#{} {C:inactive}[#3#]{} {C:attention}Jolly Jokers{} sold",
# 					"{C:inactive}(Currently{}{C:attention:} #1#{}{C:inactive} retriggers){}"
# 				}
# 			},
# 			j_cry_mneon = {
# 				name = "Neon M",
# 				text = {
# 					"Earn {C:money}$#2#{} at end of round",
# 					"Increase payout by",
# 					"{C:money}$#1#{} for each {C:attention}Jolly Joker{}",
# 					"at end of round",
# 					"{C:inactive}(Minimum increase of{} {C:money}$1{}{C:inactive}){}"
# 				}
# 			},
# 			j_cry_notebook = {
# 				name = "记事本",
# 				text = {
# 					"每次 {C:attention}重掷{}商店有{C:green} #1# in #2#{} 几率增加{C:dark_edition}+1{}个小丑牌槽位",
# 					"如果有{C:attention}#5#{} 或以上 {C:attention}开心小丑{}{C:green}百分百触发{}",
# 					"{C:red}每回合只触发一次{}",
# 					"{C:inactive}(当前{C:dark_edition}+#3#{}{C:inactive} 并且#4#){}"
# 				}
# 			},
# 			j_cry_bonk = {
# 				name = "Bonk",
# 				text = {
# 					"Each {C:attention}Joker{} gives {C:chips}+#1#{} Chips",
# 					"Increase amount by {C:chips}+#2#{} if",
# 					"{C:attention} poker hand{} is a {C:attention}#3#{}",
# 					"{C:inactive,s:0.8}Jolly Jokers give{} {C:chips,s:0.8}+#4#{} {C:inactive,s:0.8}Chips instead{}"
# 				}
# 			},
# 			j_cry_loopy = {
# 				name = "Loopy",
# 				text = {
# 					"{C:attention}Retrigger{} all Jokers",
# 					"once for each {C:attention}Jolly{}",
# 					"{C:attention}Joker{} sold this round",
# 					"{C:inactive}(Currently{}{C:attention:} #1#{}{C:inactive} Retrigger#2#){}",
# 					"{C:inactive,s:0.8}There wasn't enough room...{}"
# 				}
# 			},
# 			j_cry_scrabble = {
# 				name = "Scrabble Tile",
# 				text = {
# 					"{C:green}#1# in #2#{} chance to create",
# 					"a {C:dark_edition}Jolly {C:green}Uncommon{} Joker",
# 					"when hand is played"
# 				}
# 			},
# 			j_cry_sacrifice = {
# 				name = "Sacrifice",
# 				text = {
# 					"Create an {C:green}Uncommon{} Joker",
# 					"and 3 {C:attention}Jolly Jokers{} when",
# 					"a {C:spectral}Spectral{} card is used",
# 					"{C:red}Works once per round{}",
# 					"{C:inactive}#1#{}"
# 				}
# 			},
# 			j_cry_reverse = {
# 				name = "Reverse Card",
# 				text = {
# 					"Fill all empty Joker slots {C:inactive}(Max 100){}",
# 					"with {C:dark_edition}Holographic{} {C:attention}Jolly Jokers{} if",
# 					"{C:attention}discarded poker hand{} is a {C:attention}#1#{}",
# 					"{C:red,E:2}self destructs{}",
# 					"{C:inactive,s:0.8}The ULTIMATE comeback{}"
# 				}
# 			},
# 			j_cry_doodlem = {
# 				name = "Doodle M",
# 				text = {
# 					"Create 2 {C:dark_edition}Negative{} {C:attention}consumables{}",
# 					"when {C:attention}Blind{} is selected",
# 					"Create 1 more {C:attention}consumable",
# 					"for each {C:attention}Jolly Joker{}"
# 				}
# 			},
# 			j_cry_virgo = {
# 				name = "Virgo",
# 				text = {
# 					"This Joker gains {C:money}$#1#{} of {C:attention}sell value{}",
# 					"if {C:attention}poker hand{} contains a {C:attention}#2#{}",
# 					"Sell this card to create a",
# 					"{C:dark_edition}Polychrome{} {C:attention}Jolly Joker{} for",
# 					"every {C:money}$4{} of {C:attention}sell value{} {C:inactive}(Min 1){}"
# 				}
# 			},
# 			j_cry_smallestm = {
# 				name = "Tiny",
# 				text = {
# 					"{X:chips,C:white} X#1# {} Chips until end",
# 					"of round if {C:attention}poker hand{}",
# 					"is a {C:attention}#2#{}",
# 					"{C:inactive}(Currently {C:attention}#3#{}{C:inactive}){}",
# 					"{C:inactive,s:0.8}ok so basically i'm very smol"
# 				}
# 			},
# 			j_cry_biggestm = {
# 				name = "Huge",
# 				text = {
# 					"{X:mult,C:white} X#1# {} Mult until end",
# 					"of round if {C:attention}poker hand{}",
# 					"is a {C:attention}#2#{}",
# 					"{C:inactive}(Currently {C:attention}#3#{}{C:inactive}){}",
# 					"{C:inactive,s:0.8}not fat, just big boned."
# 				}
# 			},
# 			j_cry_mprime = {
# 				name = "Tredecim",
# 				text = {
# 					"Create up to 4 {C:attention}Jolly Jokers{} when obtained",
# 					"Each {C:attention}Jolly Joker{} gives {X:dark_edition,C:white}^#1#{} Mult",
# 					"Increase amount by {X:dark_edition,C:white}^#2#{} and",
# 					"create an {C:legendary}M Joker{} {C:red}once per round",
# 					"when a {C:attention}Jolly Joker{} is {C:attention}sold",
# 					"{C:inactive,s:0.8}(Tredecim excluded)"
# 				}
# 			},
# 			j_cry_macabre = {
# 				name = "骇人小丑",
# 				text = {
# 					"当选择{C:attention}盲注{}时，除了{C:attention}开心小丑{}和{C:legendary}M系小丑{}",
# 					"其余小丑全部摧毁，与此同时每摧毁一张就获得一张{C:attention}开心小丑{}"
# 				}
# 			},
# 			j_cry_Megg = {
# 				name = "Megg",
# 				text = {
# 					"Sell this card to create",
# 					"{C:attention}#2#{} Jolly #3#, increase",
# 					"by {C:attention}#1#{} at end of round"
# 				}
# 			},
# 			j_cry_dropshot = {
# 				name = "Dropshot",
# 				text = {
# 					"每次出牌增加 {X:mult,C:white} X#1# {} 倍率,",
# 					" {C:attention}nonscoring{} {V:1}#2#{} 卡,花色每回合改变",
# 					"{C:inactive}(Currently {X:mult,C:white} X#3# {C:inactive} Mult)"
# 				}
# 			},
# 			j_cry_happyhouse = {
# 				name = "Happy House",
# 				text = {
# 					"{X:dark_edition,C:white}^#1#{} 倍率当",
# 					" {C:attention}114{} 次出牌{}后",
# 					"{C:inactive}(Currently #2#/114){}",
# 					"{C:inactive,s:0.8}没有地方能比得上家!{}"
# 				}
# 			},
# 			j_cry_maximized = {
# 				name = "拉满！拉满！",
# 				text = {
# 					"所有{C:attention}人头牌{}都当作是{C:attention}K{}，",
# 					"所有{C:attention}数字牌{}都当作是{C:attention}10s{}，"
# 				}
# 			},
# 			j_cry_pot_of_jokes = {
# 				name = "小丑壶",
# 				text = {
# 					"减少{C:attention}#1#{}手牌数,",
# 					"每回合增加{C:blue}#2#{} "
# 				}
# 			},
# 			j_cry_wee_fib = {
# 				name = "Weebonacci",
# 				text = {
# 					"This Joker gains",
# 					"{C:mult}+#2#{} Mult when each played",
# 					"{C:attention}Ace{}, {C:attention}2{}, {C:attention}3{}, {C:attention}5{}, or {C:attention}8{}",
# 					"is scored",
# 					"{C:inactive}(Currently {C:mult}+#1#{C:inactive} Mult)"
# 				}
# 			},
# 			j_cry_whip = {
# 				name = "The WHIP",
# 				text = {
# 					"This Joker gains {X:mult,C:white} X#1# {} Mult",
# 					"if {C:attention}played hand{} contains a",
# 					"{C:attention}2{} and {C:attention}7{} of different suits",
# 					"{C:inactive}(Currently {X:mult,C:white} X#2# {C:inactive} Mult)"
# 				}
# 			},
# 			j_cry_lucky_joker = {
# 				name = "幸运小丑",
# 				text = {
# 					"Earn {C:money}$#1#{} every time a",
# 					"{C:attention}Lucky{} card {C:green}successfully{}",
# 					"triggers"
# 				}
# 			},
# 			j_cry_cursor = {
# 				name = "光标",
# 				text = {
# 					"This Joker gains {C:chips}+#2#{} Chips",
# 					"for each card {C:attention}purchased{}",
# 					"{C:inactive}(Currently {C:chips}+#1#{C:inactive} Chips)"
# 				}
# 			},
# 			j_cry_pickle = {
# 				name = "腌黄瓜",
# 				text = {
# 					"当跳过 {C:attention}盲注{} 时，创建{C:attention}#1#{} 个标签",
# 					"当选择 {C:attention}盲注{} 时，则减少{C:red}#2#{} "
# 				}
# 			},
# 			j_cry_cube = {
# 				name = "小方块",
# 				text = {
# 					"{C:chips}+#1#{} 筹码"
# 				}
# 			},
# 			j_cry_triplet_rhythm = {
# 				name = "Triplet Rhythm",
# 				text = {
# 					"{X:mult,C:white} X#1# {} Mult if scoring hand",
# 					"contains {C:attention}exactly{} three {C:attention}3s"
# 				}
# 			},
# 			j_cry_booster = {
# 				name = "Booster Joker",
# 				text = {
# 					"{C:attention}+#1#{} Booster Pack slot",
# 					"available in shop"
# 				}
# 			},
# 			j_cry_chili_pepper = {
# 				name = "Chili Pepper",
# 				text = {
# 					"This Joker gains {X:mult,C:white} X#2# {} Mult",
# 					"at end of round,",
# 					"{C:red,E:2}self destructs{} after {C:attention}#3#{} rounds",
# 					"{C:inactive}(Currently{} {X:mult,C:white} X#1# {} {C:inactive}Mult){}"
# 				}
# 			},
# 			j_cry_compound_interest = {
# 				name = "Compound Interest",
# 				text = {
# 					"Earn {C:money}#1#%{} of total money",
# 					"at end of round,",
# 					"increases by {C:money}#2#%{} per",
# 					"consecutive payout"
# 				}
# 			},
# 			j_cry_big_cube = {
# 				name = "大方块",
# 				text = {
# 					"{X:chips,C:white} X#1# {} Chips"
# 				}
# 			},
# 			j_cry_eternalflame = {
# 				name = "Eternal Flame",
# 				text = {
# 					"This Joker gains {X:mult,C:white} X#1# {} Mult",
# 					"for each card {C:attention}sold{}",
# 					"{C:inactive}(Currently {X:mult,C:white} X#2# {C:inactive} Mult)"
# 				}
# 			},
# 			j_cry_nice = {
# 				name = "歪嘴小丑",
# 				text = {
# 					"如果出牌包含一个{C:attention}6{}和{C:attention}9{}",
# 					"筹码{C:chips}+#1#{}",
# 					"{C:inactive,s:0.8}Nice.{}",
# 					""
# 				}
# 			},
# 			j_cry_seal_the_deal = {
# 				name = "Seal the Deal",
# 				text = {
# 					"Add a {C:attention}random seal{} to each card",
# 					"scored on {C:attention}final hand{} of round"
# 				}
# 			},
# 			j_cry_chad = {
# 				name = "Chad",
# 				text = {
# 					"Retrigger {C:attention}leftmost{} Joker",
# 					"{C:attention}#1#{} additional time(s)"
# 				}
# 			},
# 			j_cry_jimball = {
# 				name = "Jimball",
# 				text = {
# 					"This Joker gains {X:mult,C:white} X#1# {} Mult",
# 					"per {C:attention}consecutive{} hand played",
# 					"while playing your",
# 					"most played {C:attention}poker hand",
# 					"{C:inactive}(Currently {X:mult,C:white} X#2# {C:inactive} Mult)"
# 				}
# 			},
# 			j_cry_sus = {
# 				name = "生性多疑小丑",
# 				text = {
# 					"At end of round, create",
# 					"a {C:attention}copy{} of a random",
# 					"card {C:attention}held in hand{},",
# 					"destroy all others",
# 					"{C:hearts,s:0.8}红桃K{s:0.8} 优先考虑"
# 				}
# 			},
# 			j_cry_fspinner = {
# 				name = "Fidget Spinner",
# 				text = {
# 					"当打出的牌型不是最常用的牌型时",
# 					"这张小丑牌增加 {C:chips}+#2#{} 筹码",
# 					"{C:inactive}(当前{C:chips}+#1#{C:inactive} 筹码)"
# 				}
# 			},
# 			j_cry_luigi = {
# 				name = "Luigi",
# 				text = {
# 					"所有小丑提供",
# 					"{X:chips,C:white} X#1# {} 筹码"
# 				}
# 			},
# 			j_cry_waluigi = {
# 				name = "Waluigi",
# 				text = {
# 					"所有小丑提供",
# 					"{X:mult,C:white} X#1# {} 倍率"
# 				}
# 			},
# 			j_cry_mario = {
# 				name = "Mario",
# 				text = {
# 					"额外触发所有小丑",
# 					"{C:attention}#1#{} 次"
# 				}
# 			},
# 			j_cry_wario = {
# 				name = "Wario",
# 				text = {
# 					"触发时所有小丑提供{C:money}$#1#{}"
# 				}
# 			},
# 			j_cry_krustytheclown = {
# 				name = "Krusty the Clown",
# 				text = {
# 					"当出的每张牌都计分时",
# 					"这张牌增加{X:mult,C:white} X#1# {}倍率",
# 					"{C:inactive}(当前{X:mult,C:white} X#2# {C:inactive} 倍率)"
# 				}
# 			},
# 			j_cry_blurred = {
# 				name = "模糊小丑",
# 				text = {
# 					"选择{C:attention}盲注{}时增加",
# 					"{C:blue}+#1#{}次出牌"
# 				}
# 			},
# 			j_cry_gardenfork = {
# 				name = "《小径分岔的花园》",
# 				text = {
# 					"每 {C:attention}出{} 一张{C:attention}Ace{}和{C:attention}7{}",
# 					"赚 {C:money}$#1#{} "
# 				}
# 			},
# 			j_cry_lightupthenight = {
# 				name = "?Light Up the Night?",
# 				text = {
# 					"出的每张 {C:attention}7{} 或 {C:attention}2{}在计分时",
# 					"提供 {X:mult,C:white}X#1#{} 倍率"
# 				}
# 			},
# 			j_cry_nosound = {
# 				name = "无声残缺",
# 				text = {
# 					"每张打出的 {C:attention}7{}触发{C:attention:}#1#{} 次"
# 				}
# 			},
# 			j_cry_antennastoheaven = {
# 				name = "...Like Antennas to Heaven",
# 				text = {
# 					"每张被计入分数的 {C:attention}7{} 或 {C:attention}4{}",
# 					"增加{X:chips,C:white} X#1# {} 筹码",
# 					"{C:inactive}(当前已增加 {X:chips,C:white}X#2# {C:inactive} 筹码)"
# 				}
# 			},
# 			j_cry_hunger = {
# 				name = "Consume-able",
# 				text = {
# 					"使用一张{C:attention}消耗牌{}",
# 					"获得{C:money}$#1#{} "
# 				}
# 			},
# 			j_cry_weegaming = {
# 				name = "2D",
# 				text = {
# 					"额外重新触发每张打过的牌{C:attention}2{}{C:attention:}#1#{} 次",
# 					"{C:inactive,s:0.8}Wee Gaming?{}"
# 				}
# 			},
# 			j_cry_redbloon = {
# 				name = "Red Bloon",
# 				text = {
# 					"{C:attention}#2#{} 回合#3#后{C:red,E:2}自毁{}并获得{C:money}$#1#{}"
# 				}
# 			},
# 			j_cry_apjoker = {
# 				name = "AP Joker",
# 				text = {
# 					"{X:mult,C:white} X#1# {} Mult against {C:attention}Boss Blinds{}"
# 				}
# 			},
# 			j_cry_maze = {
# 				name = "Labyrinth",
# 				text = {
# 					"所有出牌都看作是每回合{C:attention}第一次出牌{}",
# 					"所有弃牌都看作是每回合{C:attention}第一次弃牌{}"
# 				}
# 			},
# 			j_cry_panopticon = {
# 				name = "Panopticon",
# 				text = {
# 					"所有出牌都看作是每回合{C:attention}最后一次出牌{}"
# 				}
# 			},
# 			j_cry_magnet = {
# 				name = "Fridge Magnet",
# 				text = {
# 					"最后一回合获得{C:money}$#1#{} ",
# 					"如果有少于或等于{C:attention}#3#{} 张小丑牌，获得 {X:money,C:white} X#2# {}",
# 					""
# 				}
# 			},
# 			j_cry_unjust_dagger = {
# 				name = "Unjust Dagger",
# 				text = {
# 					"When {C:attention}Blind{} is selected,",
# 					"destroy Joker to the left",
# 					"and gain {C:attention}one-fifth{} of",
# 					"its sell value as {X:mult,C:white} XMult {}",
# 					"{C:inactive}(Currently {X:mult,C:white} X#1# {C:inactive} Mult)"
# 				}
# 			},
# 			j_cry_monkey_dagger = {
# 				name = "Monkey Dagger",
# 				text = {
# 					"When {C:attention}Blind{} is selected,",
# 					"destroy Joker to the left",
# 					"and permanently add {C:attention}ten times{}",
# 					"its sell value to this {C:chips}Chips{}",
# 					"{C:inactive}(Currently {C:chips}+#1#{C:inactive} Chips)"
# 				}
# 			},
# 			j_cry_pirate_dagger = {
# 				name = "Pirate Dagger",
# 				text = {
# 					"When {C:attention}Blind{} is selected,",
# 					"destroy Joker to the right",
# 					"and gain {C:attention}one-fourth{} of",
# 					"its sell value as {X:chips,C:white} XChips {}",
# 					"{C:inactive}(Currently {X:chips,C:white} X#1# {C:inactive} Chips)"
# 				}
# 			},
# 			j_cry_mondrian = {
# 				name = "Mondrian",
# 				text = {
# 					"This Joker gains {X:mult,C:white} X#1# {} Mult",
# 					"if no {C:attention}discards{} were",
# 					"used this round",
# 					"{C:inactive}(Currently {X:mult,C:white} X#2# {C:inactive} Mult)"
# 				}
# 			},
# 			j_cry_sapling = {
# 				name = "Sapling",
# 				text = {
# 					"After scoring {C:attention}#2#{} {C:inactive}[#1#]{} Enhanced",
# 					"cards, sell this card to",
# 					"create an {C:cry_epic}Epic{} {C:attention}Joker{}",
# 					"{C:inactive,s:0.8}Will create a {C:red,s:0.8}Rare{} {C:attention,s:0.8}Joker{}",
# 					"{C:inactive,s:0.8}if {C:cry_epic,s:0.8}Epic{} {C:inactive,s:0.8}Jokers are disabled{}"
# 				}
# 			},
# 			j_cry_spaceglobe = {
# 				name = "Celestial Globe",
# 				text = {
# 					"This Joker gains {X:chips,C:white}X#2#{} Chips",
# 					"if {C:attention}poker hand{} is a {C:attention}#3#{},",
# 					"Hand changes after increase{}",
# 					"{C:inactive}(Currently{} {X:chips,C:white}X#1#{} {C:inactive}Chips){}"
# 				}
# 			},
# 			j_cry_happy = {
# 				name = ":D",
# 				text = {
# 					"Create a random {C:attention}Joker{}",
# 					"at end of round",
# 					"Sell this card to",
# 					"create a random {C:attention}Joker{}",
# 					"{C:inactive}(Must have room){}"
# 				}
# 			},
# 			j_cry_meteor = {
# 				name = "Meteor Shower",
# 				text = {
# 					"{C:dark_edition}Foil{} cards each",
# 					"give {C:chips}+#1#{} Chips",
# 					"{C:inactive,s:0.8}Effect does not trigger",
# 					"{C:inactive,s:0.8}on Meteor Shower"
# 				}
# 			},
# 			j_cry_exoplanet = {
# 				name = "Exoplanet",
# 				text = {
# 					"{C:dark_edition}Holographic{} cards",
# 					"each give {C:mult}+#1#{} Mult",
# 					"{C:inactive,s:0.8}Effect does not trigger",
# 					"{C:inactive,s:0.8}on Exoplanet"
# 				}
# 			},
# 			j_cry_stardust = {
# 				name = "Stardust",
# 				text = {
# 					"{C:dark_edition}Polychrome{} cards",
# 					"each give {X:mult,C:white}X#1#{} Mult",
# 					"{C:inactive,s:0.8}Effect does not trigger",
# 					"{C:inactive,s:0.8}on Stardust"
# 				}
# 			},
# 			j_cry_rnjoker = {
# 				name = "RNJoker",
# 				text = {
# 					"Randomize abilities each {C:attention}Ante{}"
# 				}
# 			},
# 			j_cry_duos = {
# 				name = "The Duos",
# 				text = {
# 					"{X:mult,C:white} X#1# {} Mult if played",
# 					"hand contains",
# 					"a {C:attention}#2#"
# 				}
# 			},
# 			j_cry_home = {
# 				name = "The Home",
# 				text = {
# 					"{X:mult,C:white} X#1# {} Mult if played",
# 					"hand contains",
# 					"a {C:attention}#2#"
# 				}
# 			},
# 			j_cry_nuts = {
# 				name = "The Nuts",
# 				text = {
# 					"{X:mult,C:white} X#1# {} Mult if played",
# 					"hand contains",
# 					"a {C:attention}#2#"
# 				}
# 			},
# 			j_cry_quintet = {
# 				name = "The Quintet",
# 				text = {
# 					"{X:mult,C:white} X#1# {} Mult if played",
# 					"hand contains",
# 					"a {C:attention}#2#"
# 				}
# 			},
# 			j_cry_unity = {
# 				name = "The Unity",
# 				text = {
# 					"{X:mult,C:white} X#1# {} Mult if played",
# 					"hand contains",
# 					"a {C:attention}#2#"
# 				}
# 			},
# 			j_cry_swarm = {
# 				name = "The Swarm",
# 				text = {
# 					"{X:mult,C:white} X#1# {} Mult if played",
# 					"hand contains",
# 					"a {C:attention}#2#"
# 				}
# 			},
# 			j_cry_filler = {
# 				name = "The Filler",
# 				text = {
# 					"",
# 					"如果出的牌中包含{C:attention}#2# 提供{X:mult,C:white} X#1# {} 倍率"
# 				}
# 			},
# 			j_cry_coin = {
# 				name = "Crypto Coin",
# 				text = {
# 					"每卖一个小丑获得{C:money}$#1#{}到 {C:money}$#2#{}"
# 				}
# 			},
# 			j_cry_wheelhope = {
# 				name = "Wheel of Hope",
# 				text = {
# 					"当{C:attention}命运之轮{}效果失败",
# 					"这张牌增加{X:mult,C:white} X#1# {} 倍率",
# 					"{C:inactive}(当前{X:mult,C:white} X#2# {C:inactive} 倍率)"
# 				}
# 			},
# 			j_cry_oldblueprint = {
# 				name = "残缺蓝图",
# 				text = {
# 					"复制右边小丑牌的能力",
# 					"每回合后有{C:green}#1# / #2#{} 的几率自毁",
# 					""
# 				}
# 			},
# 			j_cry_night = {
# 				name = "夜晚",
# 				text = {
# 					"",
# 					"最后一次出牌提供{X:dark_edition,C:white}^#1#{} 倍率，但自毁"
# 				}
# 			},
# 			j_cry_busdriver = {
# 				name = "Bus Driver",
# 				text = {
# 					"{C:green}#1# / #3#{} 概率 {C:mult}+#2#{} Mult",
# 					"或{C:green}1 /4{} 概率 {C:mult}-#2#{} Mult"
# 				}
# 			},
# 			j_cry_translucent = {
# 				name = "Translucent Joker",
# 				text = {
# 					"卖掉这张卡从现有的小丑中随机复制一张 ",
# 					"带有{C:attention}易腐{}和{C:attention}香蕉{}{C:attention}小丑{}",
# 					"{s:0.8,C:inactive}(不会复制易腐)"
# 				}
# 			},
# 			j_cry_morse = {
# 				name = "Morse Code",
# 				text = {
# 					"在回合结尾获得 {C:money}$#2#{}",
# 					"每卖掉一张 {C:attention}增强卡牌{}增加 {C:money}$#1#{}",
# 					"{C:red}每回合生效一次{}",
# 					"{C:inactive}#3#{}"
# 				}
# 			},
# 			j_cry_membershipcard = {
# 				name = "Membership Card",
# 				text = {
# 					"Cryptid Discord{}中的每个成员提供这张牌{X:mult,C:white}X#1#{}  {C:attention}倍率",
# 					"{C:inactive}(当前{X:mult,C:white}X#2#{C:inactive} 倍率)",
# 					"{C:blue,s:0.7}https://discord.gg/eUf9Ur6RyB{}"
# 				}
# 			},
# 			j_cry_kscope = {
# 				name = "Kaleidoscope",
# 				text = {
# 					"当击败{C:attention}Boss 盲注{}时",
# 					"增加一张随机的{C:dark_edition}Polychrome{}  {C:attention}小丑{}"
# 				}
# 			},
# 			j_cry_cryptidmoment = {
# 				name = "M Chain",
# 				text = {
# 					"",
# 					"卖掉这张卡每张{C:attention}小丑牌{}的售价增加 {C:money}$#1#{}"
# 				}
# 			}
# 		},
# 		Seal = {
# 			s_cry_green = {
# 				name = "Green Seal",
# 				text = {
# 					"Creates a {C:cry_code}Code{} card",
# 					"when played and unscoring",
# 					"{C:inactive}(Must have room)"
# 				}
# 			},
# 			s_cry_azure = {
# 				name = "Azure Seal",
# 				text = {
# 					"Create {C:attention}#1#{} {C:dark_edition}Negative{}",
# 					"{C:planet}Planets{} for played",
# 					"{C:attention}poker hand{}, then",
# 					"{C:red}destroy{} this card"
# 				}
# 			}
# 		},
# 		Stake = {
# 			s_cry_pink = {
# 				name = "Pink Stake",
# 				text = {
# 					"Required score scales",
# 					"faster for each {C:attention}Ante"
# 				}
# 			},
# 			s_cry_brown = {
# 				name = "Brown Stake",
# 				text = {
# 					"All {C:attention}stickers{} are compatible",
# 					"with each other"
# 				}
# 			},
# 			s_cry_yellow = {
# 				name = "Yellow Stake",
# 				text = {
# 					"{C:attention}Stickers{} can appear on",
# 					"all purchasable items"
# 				}
# 			},
# 			s_cry_jade = {
# 				name = "Jade Stake",
# 				text = {
# 					"Cards can be drawn {C:attention}face down{}"
# 				}
# 			},
# 			s_cry_cyan = {
# 				name = "Cyan Stake",
# 				text = {
# 					"{C:green}Uncommon{} and {C:red}Rare{} Jokers are",
# 					"less likely to appear"
# 				}
# 			},
# 			s_cry_gray = {
# 				name = "Gray Stake",
# 				text = {
# 					"Rerolls increase by {C:attention}$2{} each"
# 				}
# 			},
# 			s_cry_crimson = {
# 				name = "Crimson Stake",
# 				text = {
# 					"Vouchers restock on {C:attention}even{} Antes"
# 				}
# 			},
# 			s_cry_diamond = {
# 				name = "Diamond Stake",
# 				text = {
# 					"Must beat Ante {C:attention}10{} to win"
# 				}
# 			},
# 			s_cry_amber = {
# 				name = "Amber Stake",
# 				text = {
# 					"{C:attention}-1{} Booster Pack slot"
# 				}
# 			},
# 			s_cry_bronze = {
# 				name = "Bronze Stake",
# 				text = {
# 					"Vouchers are {C:attention}50%{} more expensive"
# 				}
# 			},
# 			s_cry_quartz = {
# 				name = "Quartz Stake",
# 				text = {
# 					"Jokers can be {C:attention}Pinned{}",
# 					"{s:0.8,C:inactive}(Stays pinned to the leftmost position){}"
# 				}
# 			},
# 			s_cry_ruby = {
# 				name = "Ruby Stake",
# 				text = {
# 					"{C:attention}Big{} Blinds can become",
# 					"{C:attention}Boss{} Blinds"
# 				}
# 			},
# 			s_cry_glass = {
# 				name = "Glass Stake",
# 				text = {
# 					"Cards can {C:attention}shatter{} when scored"
# 				}
# 			},
# 			s_cry_sapphire = {
# 				name = "Sapphire Stake",
# 				text = {
# 					"Lose {C:attention}25%{} of current money",
# 					"at end of Ante",
# 					"{s:0.8,C:inactive}(Up to $10){}"
# 				}
# 			},
# 			s_cry_emerald = {
# 				name = "Emerald Stake",
# 				text = {
# 					"Cards, packs, and vouchers",
# 					"can be {C:attention}face down{}",
# 					"{s:0.8,C:inactive}(Unable to be viewed until purchased){}"
# 				}
# 			},
# 			s_cry_platinum = {
# 				name = "Platinum Stake",
# 				text = {
# 					"Small Blinds are {C:attention}removed{}"
# 				}
# 			},
# 			s_cry_twilight = {
# 				name = "Twilight Stake",
# 				text = {
# 					"Cards can be {C:attention}Banana{}",
# 					"{s:0.8,C:inactive}(1 in 10 chance of being destroyed each round){}"
# 				}
# 			},
# 			s_cry_verdant = {
# 				name = "Verdant Stake",
# 				text = {
# 					"Required score scales",
# 					"faster for each {C:attention}Ante"
# 				}
# 			},
# 			s_cry_ember = {
# 				name = "Ember Stake",
# 				text = {
# 					"All items give no money when sold"
# 				}
# 			},
# 			s_cry_dawn = {
# 				name = "Dawn Stake",
# 				text = {
# 					"Tarots and Spectrals target {C:attention}1",
# 					"fewer card",
# 					"{s:0.8,C:inactive}(Minimum of 1){}"
# 				}
# 			},
# 			s_cry_horizon = {
# 				name = "Horizon Stake",
# 				text = {
# 					"When blind selected, add a",
# 					"{C:attention}random card{} to deck"
# 				}
# 			},
# 			s_cry_blossom = {
# 				name = "Blossom Stake",
# 				text = {
# 					"{C:attention}Final{} Boss Blinds can appear",
# 					"in {C:attention}any{} Ante"
# 				}
# 			},
# 			s_cry_azure = {
# 				name = "Azure Stake",
# 				text = {
# 					"Values on Jokers are reduced",
# 					"by {C:attention}20%{}"
# 				}
# 			},
# 			s_cry_ascendant = {
# 				name = "Ascendant Stake",
# 				text = {
# 					"{C:attention}-1{} Shop slot"
# 				}
# 			}
# 		},
# 		Tag = {
# 			t_cry_console = {
# 				name = "Console Tag",
# 				text = {
# 					"Gives a free",
# 					"{C:cry_code}Program Pack"
# 				}
# 			},
# 			t_cry_rework = {
# 				name = "Rework Tag",
# 				text = {
# 					"Shop has a(n)",
# 					"{C:dark_edition}#1# {C:cry_code}#2#"
# 				}
# 			},
# 			t_cry_cat = {
# 				name = "Cat Tag",
# 				text = {
# 					"Meow.",
# 					"{C:inactive}Level {C:dark_edition}#1#"
# 				}
# 			},
# 			t_cry_epic = {
# 				name = "Epic Tag",
# 				text = {
# 					"Shop has a half-price",
# 					"{C:cry_epic}Epic Joker"
# 				}
# 			},
# 			t_cry_schematic = {
# 				name = "Schematic Tag",
# 				text = {
# 					"Shop has a",
# 					"{C:attention}Brainstorm"
# 				}
# 			},
# 			t_cry_empowered = {
# 				name = "Empowered Tag",
# 				text = {
# 					"Gives a free {C:spectral}Spectral Pack",
# 					"with {C:legendary,E:1}The Soul{} and {C:cry_exotic,E:1}Gateway{}"
# 				}
# 			},
# 			t_cry_bundle = {
# 				name = "Bundle Tag",
# 				text = {
# 					"Create a {C:attention}Standard Tag{}, {C:tarot}Charm Tag{},",
# 					"{C:attention}Buffoon Tag{}, and {C:planet}Meteor Tag"
# 				}
# 			},
# 			t_cry_memory = {
# 				name = "Memory Tag",
# 				text = {
# 					"Create {C:attention}#1#{} copies of",
# 					"the last {C:attention}Tag{} used",
# 					"during this run",
# 					"{s:0.8,C:inactive}Copying Tags excluded",
# 					"{s:0.8,C:inactive}Currently: {s:0.8,C:attention}#2#"
# 				}
# 			},
# 			t_cry_triple = {
# 				name = "Triple Tag",
# 				text = {
# 					"Gives {C:attention}#1#{} copies of the",
# 					"next selected {C:attention}Tag",
# 					"{s:0.8,C:inactive}Copying Tags excluded"
# 				}
# 			},
# 			t_cry_quadruple = {
# 				name = "Quadruple Tag",
# 				text = {
# 					"Gives {C:attention}#1#{} copies of the",
# 					"next selected {C:attention}Tag",
# 					"{s:0.8,C:inactive}Copying Tags excluded"
# 				}
# 			},
# 			t_cry_quintuple = {
# 				name = "Quintuple Tag",
# 				text = {
# 					"Gives {C:attention}#1#{} copies of the",
# 					"next selected {C:attention}Tag",
# 					"{s:0.8,C:inactive}Copying Tags excluded"
# 				}
# 			}
# 		},
# 		Voucher = {
# 			v_cry_copies = {
# 				name = "Copies",
# 				text = {
# 					"Double Tags become",
# 					"{C:attention}Triple Tags{} and are",
# 					"{C:attention}2X{} as common"
# 				}
# 			},
# 			v_cry_tag_printer = {
# 				name = "Tag Printer",
# 				text = {
# 					"Double Tags become",
# 					"{C:attention}Quadruple Tags{} and",
# 					"are {C:attention}3X{} as common"
# 				}
# 			},
# 			v_cry_clone_machine = {
# 				name = "Clone Machine",
# 				text = {
# 					"Double Tags become",
# 					"{C:attention}Quintuple Tags{} and",
# 					"are {C:attention}4X{} as common"
# 				}
# 			},
# 			v_cry_command_prompt = {
# 				name = "Command Prompt",
# 				text = {
# 					"{C:cry_code}Code{} cards",
# 					"can appear",
# 					"in the {C:attention}shop{}"
# 				}
# 			},
# 			v_cry_satellite_uplink = {
# 				name = "Satellite Uplink",
# 				text = {
# 					"{C:cry_code}Code{} cards may",
# 					"appear in any of",
# 					"the {C:attention}Celestial Packs{}"
# 				}
# 			},
# 			v_cry_quantum_computing = {
# 				name = "Quantum Computing",
# 				text = {
# 					"{C:cry_code}Code{} cards can spawn",
# 					"with {C:dark_edition}Negative{} edition"
# 				}
# 			},
# 			v_cry_pairing = {
# 				name = "Pairing",
# 				text = {
# 					"{C:attention}Retrigger{} all M Jokers",
# 					"if played hand is a {C:attention}Pair"
# 				}
# 			},
# 			v_cry_repair_man = {
# 				name = "Repair Man",
# 				text = {
# 					"{C:attention}Retrigger{} all M Jokers",
# 					"if played hand contains a {C:attention}Pair"
# 				}
# 			},
# 			v_cry_pairamount_plus = {
# 				name = "Pairamount Plus",
# 				text = {
# 					"{C:attention}Retrigger{} all M Jokers",
# 					"once for every Pair",
# 					"{C:attention}contained{} in played hand"
# 				}
# 			},
# 			v_cry_overstock_multi = {
# 				name = "Multistock",
# 				text = {
# 					"{C:attention}+#1#{} card slot(s) and",
# 					"{C:attention}+#1#{} booster pack slot(s)",
# 					"available in shop"
# 				}
# 			},
# 			v_cry_massproduct = {
# 				name = "Mass Production",
# 				text = {
# 					"All cards and packs",
# 					"in shop cost {C:attention}$1{}"
# 				}
# 			},
# 			v_cry_curate = {
# 				name = "Curate",
# 				text = {
# 					"All cards",
# 					"appear with",
# 					"an {C:dark_edition}Edition{}"
# 				}
# 			},
# 			v_cry_rerollexchange = {
# 				name = "Reroll Exchange",
# 				text = {
# 					"All rerolls",
# 					"cost {C:attention}$2{}"
# 				}
# 			},
# 			v_cry_scope = {
# 				name = "Galactic Scope",
# 				text = {
# 					"Create the {C:planet}Planet",
# 					"card for played",
# 					"{C:attention}poker hand{}",
# 					"{C:inactive}(Must have room){}"
# 				}
# 			},
# 			v_cry_dexterity = {
# 				name = "Dexterity",
# 				text = {
# 					"Permanently",
# 					"gain {C:blue}+#1#{} hand(s)",
# 					"each round"
# 				}
# 			},
# 			v_cry_threers = {
# 				name = "The 3 Rs",
# 				text = {
# 					"Permanently",
# 					"gain {C:red}+#1#{} discard(s)",
# 					"each round"
# 				}
# 			},
# 			v_cry_tacclimator = {
# 				name = "Tarot Acclimator",
# 				text = {
# 					"{C:tarot}Tarot{} cards appear",
# 					"{C:attention}X#1#{} more frequently",
# 					"in the shop",
# 					"All future {C:tarot}Tarot{}",
# 					"cards are {C:green}free{}"
# 				}
# 			},
# 			v_cry_pacclimator = {
# 				name = "Planet Acclimator",
# 				text = {
# 					"{C:planet}Planet{} cards appear",
# 					"{C:attention}X#1#{} more frequently",
# 					"in the shop",
# 					"All future {C:planet}Planet{}",
# 					"cards are {C:green}free{}"
# 				}
# 			},
# 			v_cry_moneybean = {
# 				name = "Money Beanstalk",
# 				text = {
# 					"Raise the cap on",
# 					"interest earned in",
# 					"each round to {C:money}$#1#{}"
# 				}
# 			},
# 			v_cry_fabric = {
# 				name = "Universal Fabric",
# 				text = {
# 					"{C:dark_edition}+#1#{} Joker slot(s)"
# 				}
# 			},
# 			v_cry_asteroglyph = {
# 				name = "Asteroglyph",
# 				text = {
# 					"Set Ante to {C:attention}#1#{}"
# 				}
# 			},
# 			v_cry_blankcanvas = {
# 				name = "Blank Canvas",
# 				text = {
# 					"{C:attention}+#1#{} hand size"
# 				}
# 			}
# 		}
# 	}
# }
